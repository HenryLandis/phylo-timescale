# %% [markdown]
# ## Node dating
#
# Running the Analysis script on node dating datasets.

# %%
from phylotimescale import Analysis
import toytree
import toyplot
import pandas as pd
import numpy as np
import ipcoal

# %%
import toyplot.svg

# %%
tre = toytree.tree("/home/henry/phylo-timescale/basetree.tre")
nodes = ['98', '78', '74', '64']
sizes = [12 if i in nodes else 0 for i in tre.get_node_values("idx", 1, 0)]
colors = ['red' if i == '98' else 'blue' for i in tre.get_node_values("idx", 1, 0)]
canvas, axes, mark = tre.draw(layout = 'd', node_sizes = sizes, node_colors = colors);
# Out:
# <div class="toyplot" id="t75087413213549c89d61829f6fcc03f8" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="265.0px" id="t76b39060a2d5481fbd5075b55320798c" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 900.0 265.0" width="900.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t15560c4670794e609c9142f0d0f0be92"><clipPath id="tb44bb0c0b4e3443faaa99a00910e09df"><rect height="205.0" width="840.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#tb44bb0c0b4e3443faaa99a00910e09df)"><g class="toytree-mark-Toytree" id="t49f819a2c36c491fb78d80f755479832"><g class="toytree-Edges" style="fill:non
# ...

# %%
import toyplot.svg
toyplot.svg.render(canvas, "/home/henry/svg/basetree.svg")

# %%
nvs = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/nvs-final.csv"))
nvr = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/nvr-final.csv"))
nvb = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/nvb-final.csv"))
vns = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vns-final.csv"))
vnr = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vnr-final.csv"))
vnb = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vnb-final.csv"))
vgs = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vgs-mb.csv"))
vgr = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vgr-mb.csv"))
vgb = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vgb-mb.csv"))
vbs = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vbs-mb.csv"))
vbr = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vbr-mb.csv"))
vbb = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vbb-mb.csv"))

# %%
nvs.run()
nvr.run()
nvb.run()
vns.run()
vnr.run()
vnb.run()
vgs.run()
vgr.run()
vgb.run()
vbs.run()
vbr.run()
vbb.run()

# %%
nvs_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/nvs-final.csv"))
nvr_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/nvr-final.csv"))
nvb_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/nvb-final.csv"))
vns_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vns-final.csv"))
vnr_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vnr-final.csv"))
vnb_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vnb-final.csv"))
vgs_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vgs-mb.csv"))
vgr_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vgr-mb.csv"))
vgb_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vgb-mb.csv"))
vbs_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vbs-mb.csv"))
vbr_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vbr-mb.csv"))
vbb_ss = Analysis(tree = "/home/henry/phylo-timescale/basetree.tre",
               df = pd.read_csv("/pinky/henry/pht_results/pht_results/csvs-final/vbb-mb.csv"))

# %%
tre.draw(layout = 'd', scalebar = True);
# Out:
# <div class="toyplot" id="t19878e5f566443aa9b81eed96e4d54be" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="265.0px" id="t15d2ba3cd6a54e3cb0d80311284deb9d" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 900.0 265.0" width="900.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t036e8d78dcd44b03a716070aaebb63d5"><clipPath id="t0af8b9a68fb64074ad4b51ee1b06f208"><rect height="205.0" width="840.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t0af8b9a68fb64074ad4b51ee1b06f208)"><g class="toytree-mark-Toytree" id="taab4fa0e99c6460f81244cd5371e2aee"><g class="toytree-Edges" style="fill:non
# ...

# %%
toytree.tree(nvs.data.at[0, "mrbayes_tree"]).draw(layout = 'd', scalebar = True);
# Out:
# <div class="toyplot" id="t6443d5cfcaf8415482cce35b42838bce" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="265.0px" id="ta616099c496740a98ea99fab2be13b4b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 900.0 265.0" width="900.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="te999d915869d4c4d93b1fe6cdff1e5d8"><clipPath id="t1c393a43570144fdb36955c2960a74ea"><rect height="205.0" width="840.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t1c393a43570144fdb36955c2960a74ea)"><g class="toytree-mark-Toytree" id="t3b49cf5d097f47d7a48fb64f89fbefb0"><g class="toytree-Edges" style="fill:non
# ...

# %%
toytree.tree(nvr.data.at[69, "mrbayes_tree"]).draw(layout = 'd', scalebar = True);
# Out:
# <div class="toyplot" id="t6e0e53543aa0475d843fa8e70d81110e" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="265.0px" id="tb075eb11bd464420bfc9e2f1f661f2bc" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 900.0 265.0" width="900.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t3c15e3ce88ab4382ad6cfbd20aebdeee"><clipPath id="t43551afd27a84e379fb630101d94a780"><rect height="205.0" width="840.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t43551afd27a84e379fb630101d94a780)"><g class="toytree-mark-Toytree" id="t77947fd0d8534308a736a93cf9e6b378"><g class="toytree-Edges" style="fill:non
# ...

# %%
toytree.tree(nvb.data.at[0, "mrbayes_tree"]).draw(layout = 'd', scalebar = True);
# Out:
# <div class="toyplot" id="ted16ae73bea845ce983a06f1123918b7" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="265.0px" id="t63ed650c46dd4b598fddedb71d49ed0c" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 900.0 265.0" width="900.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="te162d463a24247cfae598dfc29c4b908"><clipPath id="ted2dccb0f56f432e9d8731a75c020822"><rect height="205.0" width="840.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#ted2dccb0f56f432e9d8731a75c020822)"><g class="toytree-mark-Toytree" id="tb0fd4bae0c4e4abab87c3c39db4b1a16"><g class="toytree-Edges" style="fill:non
# ...

# %%
for idx in range(1, 50):
    print(tre.get_node_values("height")[idx],
         toytree.tree(nvb.data.at[25, "mrbayes_tree"]).get_node_values("height")[idx])
# Out:
# 23076980 25.446514200000003
# 23076980 28.057101000000003
# 21153900 20.498725200000003
# 21153900 22.144233200000002
# 21153900 22.938669000000004
# 21153900 27.002059000000003
# 19230820 15.826306200000005
# 19230820 16.341701200000003
# 19230820 18.208313200000006
# 19230820 18.692505200000006
# 19230820 17.095033000000004
# 19230820 16.200443000000007
# 19230820 22.518568000000002
# 19230820 26.278801600000005
# 17307740 11.599364200000004
# 17307740 13.789005200000004
# 17307740 14.258373200000005
# 17307740 16.783335200000003
# 17307740 18.327275000000007
# 17307740 17.949628000000004
# 17307740 19.641894600000004
# 17307740 25.726198100000005
# 15384660 14.200770200000004
# 15384660 12.963310200000002
# 15384660 14.527644000000004
# 15384660 22.833256100000003
# 15384660 23.614119100000003
# 13461580 10.3322982
# 13461580 10.932354200000002
# 13461580 10.1487662
# 13461580 11.252020000000002
# 13461580 16.003386100000007
# 13461580 20.000739100000004
# ...

# %%
nvs_ss.run(calc = 'ss')
nvr_ss.run(calc = 'ss')
nvb_ss.run(calc = 'ss')
vns_ss.run(calc = 'ss')
vnr_ss.run(calc = 'ss')
vnb_ss.run(calc = 'ss')
vgs_ss.run(calc = 'ss')
vgr_ss.run(calc = 'ss')
vgb_ss.run(calc = 'ss')
vbs_ss.run(calc = 'ss')
vbr_ss.run(calc = 'ss')
vbb_ss.run(calc = 'ss')

# %%
true = toytree.tree("/home/henry/phylo-timescale/basetree.tre")
test = toytree.tree(vbr.data.at[2, "mrbayes_tree"])
testmod = toytree.tree(vbb.data.at[2, "chronos_relaxed"])
testmod = testmod.mod.node_scale_root_height(list(true.get_feature_dict("height").keys())[0])

# %%
a = abs((true.get_edge_values("height")) - (testmod.get_edge_values("height"))) / (true.get_edge_values("height"))
a
# Out:
# /home/henry/miniconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([0.99985343, 0.99985343, 0.99990229, 0.99989838, 0.99988275,
#        0.99994137,        inf,        inf,        inf,        inf,
#               inf, 0.99995603, 0.99996482, 0.99996482,        inf,
#        0.99998534, 0.99996092, 0.99997069, 0.99997069, 0.9999531 ,
#        0.9999531 , 0.99996482,        inf, 0.99998534, 0.99996092,
#        1.        , 0.99997069, 0.99997069, 1.        , 1.        ,
#        1.        , 1.        , 0.99998534, 0.99998534, 0.99998534,
#        0.99998534,        inf,        inf, 0.99997655, 0.99996873,
#        0.99999414, 0.99999414, 0.99994724, 0.99994724, 0.9999531 ,
#        0.99995896, 0.99995896, 0.99997655, 0.99997655, 0.99997655,
#        0.90633517, 0.90633468, 0.87511269, 0.81266888, 0.9270918 ,
# ...

# %%
dists = []
for nidx in true.idx_dict:
    tips = true.get_tip_labels(nidx)
    test_nidx = testmod.get_mrca_idx_from_tip_labels(tips)
    testnode = testmod.idx_dict[test_nidx]
    truenode = true.idx_dict[nidx]
    diff = abs((truenode.height + 1) - (testnode.height + 1)) / (truenode.height + 1)
    dists.append(diff)
# dists
# from statistics import mean
mean(dists)
# Out:
# 0.6277573663976426

# %%
nvs.data
# Out:
#     Unnamed: 0       spp_tree    phy_seqpath    nex_seqpath  nsnps  \
# 0            0  ((((r49:1....  /moto/eato...  /moto/eato...  99976
# 1            1  ((((r49:1....  /moto/eato...  /moto/eato...  99978
# 2            2  ((((r49:1....  /moto/eato...  /moto/eato...  99974
# 3            3  ((((r49:1....  /moto/eato...  /moto/eato...  99985
# 4            4  ((((r49:1....  /moto/eato...  /moto/eato...  99975
# ..         ...            ...            ...            ...    ...
# 95          95  ((((r49:1....  /moto/eato...  /moto/eato...  99973
# 96          96  ((((r49:1....  /moto/eato...  /moto/eato...  99976
# 97          97  ((((r49:1....  /moto/eato...  /moto/eato...  99984
# 98          98  ((((r49:1....  /moto/eato...  /moto/eato...  99971
# 99          99  ((((r49:1....  /moto/eato...  /moto/eato...  99977
#
#        raxml_tree chronos_correlated  chc_simple_error  chc_relative_error  \
# 0   ((((r49:0....  ((((r49:19...          6.162e+06         6.207e+06
# ...

# %% [markdown]
# ## Mean differences in node height

# %% [markdown]
# chronos trees

# %%
canvas = toyplot.Canvas(width=1200, height=1200)
ax0 = canvas.cartesian(grid=(4, 3, 0), label = "no-var-shallow")
mark0 = ax0.bars(np.histogram(nvs.data.chr_simple_error.values), opacity = 0.25)
ax1 = canvas.cartesian(grid=(4, 3, 1), label = "no-var-root")
mark1 = ax1.bars(np.histogram(nvr.data.chr_relative_error.values), opacity = 0.25)
ax2 = canvas.cartesian(grid=(4, 3, 2), label = "no-var-full")
mark2 = ax2.bars(np.histogram(nvb.data.chr_relative_error.values), opacity = 0.25)
ax3 = canvas.cartesian(grid=(4, 3, 3), label = "vary-Ne-shallow")
mark3 = ax3.bars(np.histogram(vns.data.chr_relative_error.values), opacity = 0.25)
ax4 = canvas.cartesian(grid=(4, 3, 4), label = "vary-Ne-root")
mark4 = ax4.bars(np.histogram(vnr.data.chr_relative_error.values), opacity = 0.25)
ax5 = canvas.cartesian(grid=(4, 3, 5), label = "vary-Ne-full")
mark5 = ax5.bars(np.histogram(vnb.data.chr_relative_error.values), opacity = 0.25)
ax6 = canvas.cartesian(grid=(4, 3, 6), label = "vary-g-shallow")
mark6 = ax6.bars(np.histogram(vgs.data.chr_relative_error.values), opacity = 0.25)
ax7 = canvas.cartesian(grid=(4, 3, 7), label = "vary-g-root")
mark7 = ax7.bars(np.histogram(vgr.data.chr_relative_error.values), opacity = 0.25)
ax8 = canvas.cartesian(grid=(4, 3, 8), label = "vary-g-full")
mark8 = ax8.bars(np.histogram(vgb.data.chr_relative_error.values), opacity = 0.25)
ax9 = canvas.cartesian(grid=(4, 3, 9), label = "vary-Ne-g-shallow")
mark9 = ax9.bars(np.histogram(vbs.data.chr_relative_error.values), opacity = 0.25)
ax10 = canvas.cartesian(grid=(4, 3, 10), label = "vary-Ne-g-root")
mark10 = ax10.bars(np.histogram(vbr.data.chr_relative_error.values), opacity = 0.25)
ax11 = canvas.cartesian(grid=(4, 3, 11), label = "vary-Ne-g-full")
mark11 = ax11.bars(np.histogram(vbb.data.chr_relative_error.values), opacity = 0.25)
# Out:
# <div class="toyplot" id="t802f950b334d48c082ea7a0d9b5e8dff" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="1200.0px" id="tb938355be57946928ef650cd53233609" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1200.0 1200.0" width="1200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tc14c3ce31b61496fba4f59d503f3402d"><clipPath id="tfefaae7ad88b496c962e45d4825c73fe"><rect height="220.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tfefaae7ad88b496c962e45d4825c73fe)"><g class="toyplot-mark-BarMagnitudes" id="t47651fb6856f434980ee8cdda7561457" style="stroke:rgb(100%,100%,10
# ...

# %% [markdown]
# mrbayes trees

# %%
canvas = toyplot.Canvas(width=1200, height=1200)
locator = toyplot.locator.Extended(format="{:.3e}")
ax0 = canvas.cartesian(grid=(4, 3, 0), label = "no-var-shallow")
#ax0.x.ticks.locator = locator
mark0 = ax0.bars(np.histogram(nvs.data.mb_relative_error.values), opacity = 0.25)
ax1 = canvas.cartesian(grid=(4, 3, 1), label = "no-var-root")
#ax1.x.ticks.locator = locator
mark1 = ax1.bars(np.histogram(nvr.data.mb_relative_error.values), opacity = 0.25)
ax2 = canvas.cartesian(grid=(4, 3, 2), label = "no-var-full")
#ax2.x.ticks.locator = locator
mark2 = ax2.bars(np.histogram(nvb.data.mb_relative_error.values), opacity = 0.25)
ax3 = canvas.cartesian(grid=(4, 3, 3), label = "vary-Ne-shallow")
#ax3.x.ticks.locator = locator
mark3 = ax3.bars(np.histogram(vns.data.mb_relative_error.values), opacity = 0.25)
ax4 = canvas.cartesian(grid=(4, 3, 4), label = "vary-Ne-root")
#ax4.x.ticks.locator = locator
mark4 = ax4.bars(np.histogram(vnr.data.mb_relative_error.values), opacity = 0.25)
ax5 = canvas.cartesian(grid=(4, 3, 5), label = "vary-Ne-full")
#ax5.x.ticks.locator = locator
mark5 = ax5.bars(np.histogram(vnb.data.mb_relative_error.values), opacity = 0.25)
ax6 = canvas.cartesian(grid=(4, 3, 6), label = "vary-g-shallow")
#ax6.x.ticks.locator = locator
mark6 = ax6.bars(np.histogram(vgs.data.mb_relative_error.values), opacity = 0.25)
ax7 = canvas.cartesian(grid=(4, 3, 7), label = "vary-g-root")
#ax7.x.ticks.locator = locator
mark7 = ax7.bars(np.histogram(vgr.data.mb_relative_error.values), opacity = 0.25)
ax8 = canvas.cartesian(grid=(4, 3, 8), label = "vary-g-full")
#ax8.x.ticks.locator = locator
mark8 = ax8.bars(np.histogram(vgb.data.mb_relative_error.values), opacity = 0.25)
ax9 = canvas.cartesian(grid=(4, 3, 9), label = "vary-Ne-g-shallow")
#ax9.x.ticks.locator = locator
mark9 = ax9.bars(np.histogram(vbs.data.mb_relative_error.values), opacity = 0.25)
ax10 = canvas.cartesian(grid=(4, 3, 10), label = "vary-Ne-g-root")
#ax10.x.ticks.locator = locator
mark10 = ax10.bars(np.histogram(vbr.data.mb_relative_error.values), opacity = 0.25)
ax11 = canvas.cartesian(grid=(4, 3, 11), label = "vary-Ne-g-full")
#ax11.x.ticks.locator = locator
mark11 = ax11.bars(np.histogram(vbb.data.mb_relative_error.values), opacity = 0.25)
# Out:
# <div class="toyplot" id="tc7437c30237b40ca8bf1e88f4da565cb" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="1200.0px" id="t499f45070db84ac3ad3bd6d0ce580588" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1200.0 1200.0" width="1200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="ta4a27bdedb9445deba563c304b49d298"><clipPath id="t9910f7cd79ca44e5936e98d89d2b7c99"><rect height="220.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t9910f7cd79ca44e5936e98d89d2b7c99)"><g class="toyplot-mark-BarMagnitudes" id="taefe4e66da744057a88cfa36c8d29c36" style="stroke:rgb(100%,100%,10
# ...

# %% [markdown]
# panel of chronos and mrbayes

# %%
canvas = toyplot.Canvas(width=1200, height=1200)
locator = toyplot.locator.Extended(format="{:.3e}")
ax0 = canvas.cartesian(grid=(4, 3, 0), label = "no-var-shallow")
#ax0.x.ticks.locator = locator
mark0 = ax0.bars(np.histogram(nvs.data.mb_relative_error.values), opacity = 0.25)
mark0 = ax0.bars(np.histogram(nvs.data.chc_relative_error.values), opacity = 0.25)
mark0 = ax0.bars(np.histogram(nvs.data.chr_relative_error.values), opacity = 0.25)
ax1 = canvas.cartesian(grid=(4, 3, 1), label = "no-var-root")
#ax1.x.ticks.locator = locator
mark1 = ax1.bars(np.histogram(nvr.data.mb_relative_error.values), opacity = 0.25)
mark1 = ax1.bars(np.histogram(nvr.data.chc_relative_error.values), opacity = 0.25)
mark1 = ax1.bars(np.histogram(nvr.data.chr_relative_error.values), opacity = 0.25)
ax2 = canvas.cartesian(grid=(4, 3, 2), label = "no-var-full")
#ax2.x.ticks.locator = locator
mark2 = ax2.bars(np.histogram(nvb.data.mb_relative_error.values), opacity = 0.25)
mark2 = ax2.bars(np.histogram(nvb.data.chc_relative_error.values), opacity = 0.25)
mark2 = ax2.bars(np.histogram(nvb.data.chr_relative_error.values), opacity = 0.25)
ax3 = canvas.cartesian(grid=(4, 3, 3), label = "vary-Ne-shallow")
#ax3.x.ticks.locator = locator
mark3 = ax3.bars(np.histogram(vns.data.mb_relative_error.values), opacity = 0.25)
mark3 = ax3.bars(np.histogram(vns.data.chc_relative_error.values), opacity = 0.25)
mark3 = ax3.bars(np.histogram(vns.data.chr_relative_error.values), opacity = 0.25)
ax4 = canvas.cartesian(grid=(4, 3, 4), label = "vary-Ne-root")
#ax4.x.ticks.locator = locator
mark4 = ax4.bars(np.histogram(vnr.data.mb_relative_error.values), opacity = 0.25)
mark4 = ax4.bars(np.histogram(vnr.data.chc_relative_error.values), opacity = 0.25)
mark4 = ax4.bars(np.histogram(vnr.data.chr_relative_error.values), opacity = 0.25)
ax5 = canvas.cartesian(grid=(4, 3, 5), label = "vary-Ne-full")
#ax5.x.ticks.locator = locator
mark5 = ax5.bars(np.histogram(vnb.data.mb_relative_error.values), opacity = 0.25)
mark5 = ax5.bars(np.histogram(vnb.data.chc_relative_error.values), opacity = 0.25)
mark5 = ax5.bars(np.histogram(vnb.data.chr_relative_error.values), opacity = 0.25)
ax6 = canvas.cartesian(grid=(4, 3, 6), label = "vary-g-shallow")
#ax6.x.ticks.locator = locator
mark6 = ax6.bars(np.histogram(vgs.data.mb_relative_error.values), opacity = 0.25)
mark6 = ax6.bars(np.histogram(vgs.data.chc_relative_error.values), opacity = 0.25)
mark6 = ax6.bars(np.histogram(vgs.data.chr_relative_error.values), opacity = 0.25)
ax7 = canvas.cartesian(grid=(4, 3, 7), label = "vary-g-root")
#ax7.x.ticks.locator = locator
mark7 = ax7.bars(np.histogram(vgr.data.mb_relative_error.values), opacity = 0.25)
mark7 = ax7.bars(np.histogram(vgr.data.chc_relative_error.values), opacity = 0.25)
mark7 = ax7.bars(np.histogram(vgr.data.chr_relative_error.values), opacity = 0.25)
ax8 = canvas.cartesian(grid=(4, 3, 8), label = "vary-g-full")
#ax8.x.ticks.locator = locator
mark8 = ax8.bars(np.histogram(vgb.data.mb_relative_error.values), opacity = 0.25)
mark8 = ax8.bars(np.histogram(vgb.data.chc_relative_error.values), opacity = 0.25)
mark8 = ax8.bars(np.histogram(vgb.data.chr_relative_error.values), opacity = 0.25)
ax9 = canvas.cartesian(grid=(4, 3, 9), label = "vary-Ne-g-shallow")
#ax9.x.ticks.locator = locator
mark9 = ax9.bars(np.histogram(vbs.data.mb_relative_error.values), opacity = 0.25)
mark9 = ax9.bars(np.histogram(vbs.data.chc_relative_error.values), opacity = 0.25)
mark9 = ax9.bars(np.histogram(vbs.data.chr_relative_error.values), opacity = 0.25)
ax10 = canvas.cartesian(grid=(4, 3, 10), label = "vary-Ne--g-root")
#ax10.x.ticks.locator = locator
mark10 = ax10.bars(np.histogram(vbr.data.mb_relative_error.values), opacity = 0.25)
mark10 = ax10.bars(np.histogram(vbr.data.chc_relative_error.values), opacity = 0.25)
mark10 = ax10.bars(np.histogram(vbr.data.chr_relative_error.values), opacity = 0.25)
ax11 = canvas.cartesian(grid=(4, 3, 11), label = "vary-Ne-g-full")
#ax11.x.ticks.locator = locator
mark11 = ax11.bars(np.histogram(vbb.data.mb_relative_error.values), opacity = 0.25)
mark11 = ax11.bars(np.histogram(vbb.data.chc_relative_error.values), opacity = 0.25)
mark11 = ax11.bars(np.histogram(vbb.data.chr_relative_error.values), opacity = 0.25)
# Out:
# <div class="toyplot" id="t32f478ddc1234482b2ab90099042b1ff" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="1200.0px" id="t3225d7a50d2e4e5fb02d1dba6100a13c" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1200.0 1200.0" width="1200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t7aef7f783aa54df59df62d849d449d12"><clipPath id="t0cd610641c3c423f8c139124a5e37ad9"><rect height="220.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t0cd610641c3c423f8c139124a5e37ad9)"><g class="toyplot-mark-BarMagnitudes" id="te9f10f7cd89f4b69be262434487a320c" style="stroke:rgb(100%,100%,10
# ...

# %%
toyplot.png.render(canvas, "/home/henry/png/chronos-mb-compare-2.png")

# %%
# mb simple vs relative
canvas = toyplot.Canvas(width=1200, height=1200)
locator = toyplot.locator.Extended(format="{:.3e}")
ax0 = canvas.cartesian(grid=(4, 3, 0), label = "no-var-shallow")
#ax0.x.ticks.locator = locator
mark0 = ax0.bars(np.histogram(nvs.data.mb_simple_error.values), opacity = 0.25)
mark0 = ax0.bars(np.histogram(nvs.data.mb_relative_error.values), opacity = 0.25)
ax1 = canvas.cartesian(grid=(4, 3, 1), label = "no-var-root")
#ax1.x.ticks.locator = locator
mark1 = ax1.bars(np.histogram(nvr.data.mb_simple_error.values), opacity = 0.25)
mark1 = ax1.bars(np.histogram(nvr.data.mb_relative_error.values), opacity = 0.25)
ax2 = canvas.cartesian(grid=(4, 3, 2), label = "no-var-full")
#ax2.x.ticks.locator = locator
mark2 = ax2.bars(np.histogram(nvb.data.mb_simple_error.values), opacity = 0.25)
mark2 = ax2.bars(np.histogram(nvb.data.mb_relative_error.values), opacity = 0.25)
ax3 = canvas.cartesian(grid=(4, 3, 3), label = "vary-Ne-shallow")
#ax3.x.ticks.locator = locator
mark3 = ax3.bars(np.histogram(vns.data.mb_simple_error.values), opacity = 0.25)
mark3 = ax3.bars(np.histogram(vns.data.mb_relative_error.values), opacity = 0.25)
ax4 = canvas.cartesian(grid=(4, 3, 4), label = "vary-Ne-root")
#ax4.x.ticks.locator = locator
mark4 = ax4.bars(np.histogram(vnr.data.mb_simple_error.values), opacity = 0.25)
mark4 = ax4.bars(np.histogram(vnr.data.mb_relative_error.values), opacity = 0.25)
ax5 = canvas.cartesian(grid=(4, 3, 5), label = "vary-Ne-full")
#ax5.x.ticks.locator = locator
mark5 = ax5.bars(np.histogram(vnb.data.mb_simple_error.values), opacity = 0.25)
mark5 = ax5.bars(np.histogram(vnb.data.mb_relative_error.values), opacity = 0.25)
ax6 = canvas.cartesian(grid=(4, 3, 6), label = "vary-g-shallow")
#ax6.x.ticks.locator = locator
mark6 = ax6.bars(np.histogram(vgs.data.mb_simple_error.values), opacity = 0.25)
mark6 = ax6.bars(np.histogram(vgs.data.mb_relative_error.values), opacity = 0.25)
ax7 = canvas.cartesian(grid=(4, 3, 7), label = "vary-g-root")
#ax7.x.ticks.locator = locator
mark7 = ax7.bars(np.histogram(vgr.data.mb_simple_error.values), opacity = 0.25)
mark7 = ax7.bars(np.histogram(vgr.data.mb_relative_error.values), opacity = 0.25)
ax8 = canvas.cartesian(grid=(4, 3, 8), label = "vary-g-full")
#ax8.x.ticks.locator = locator
mark8 = ax8.bars(np.histogram(vgb.data.mb_simple_error.values), opacity = 0.25)
mark8 = ax8.bars(np.histogram(vgb.data.mb_relative_error.values), opacity = 0.25)
ax9 = canvas.cartesian(grid=(4, 3, 9), label = "vary-Ne-g-shallow")
#ax9.x.ticks.locator = locator
mark9 = ax9.bars(np.histogram(vbs.data.mb_simple_error.values), opacity = 0.25)
mark9 = ax9.bars(np.histogram(vbs.data.mb_relative_error.values), opacity = 0.25)
ax10 = canvas.cartesian(grid=(4, 3, 10), label = "vary-Ne--g-root")
#ax10.x.ticks.locator = locator
mark10 = ax10.bars(np.histogram(vbr.data.mb_simple_error.values), opacity = 0.25)
mark10 = ax10.bars(np.histogram(vbr.data.mb_relative_error.values), opacity = 0.25)
ax11 = canvas.cartesian(grid=(4, 3, 11), label = "vary-Ne-g-full")
#ax11.x.ticks.locator = locator
mark11 = ax11.bars(np.histogram(vbb.data.mb_simple_error.values), opacity = 0.25)
mark11 = ax11.bars(np.histogram(vbb.data.mb_relative_error.values), opacity = 0.25)
# Out:
# <div class="toyplot" id="tf5fa5c79bbb74515a0817380dac9af38" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="1200.0px" id="t3fc6ab9138534f458715adb3bc418107" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1200.0 1200.0" width="1200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t7a71c7be977741f4b541085b0c8b03d9"><clipPath id="t9af672906c1a48ed92d76d81bdcbb877"><rect height="220.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t9af672906c1a48ed92d76d81bdcbb877)"><g class="toyplot-mark-BarMagnitudes" id="t1575c689cfec479ba7473efb54819976" style="stroke:rgb(100%,100%,10
# ...

# %%
print(mean(nvb.data.mb_relative_error.values), mean(nvs.data.mb_relative_error.values))
# Out:
# 0.18692068707431528 0.1612188384961464

# %%
# Out:
# 0.18224823028494455

# %%
import toyplot.png
toyplot.png.render(canvas, "/home/henry/png/mb_plots_2.png")

# %%
# One-way ANOVA to test if distributions of tree error are significantly different.
from scipy.stats import f_oneway
f_oneway(
    vbb.data.mb_simple_error.values, 
    vbb.data.mb_relative_error.values,
    #vgs.data.mb_relative_error.values,
    #vbs.data.mb_relative_error.values
)
# Out:
# F_onewayResult(statistic=2.3473121017773804, pvalue=0.12709542738647847)

# %%
# Tukey post-hoc test for direction of significance.
from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukey = pairwise_tukeyhsd(endog = nvb.data.mb_simple_error.values.tolist() 
                          + vnb.data.mb_simple_error.values.tolist() 
                          + vgb.data.mb_simple_error.values.tolist()
                          + vbb.data.mb_simple_error.values.tolist(),
                          groups = np.repeat(['a', 'b', 'c', 'd'], repeats=100),
                          alpha = 0.05)
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      a      b   0.0018    0.9 -0.0179 0.0214  False
#      a      c    0.002    0.9 -0.0177 0.0217  False
#      a      d   0.0061 0.8373 -0.0136 0.0257  False
#      b      c   0.0002    0.9 -0.0194 0.0199  False
#      b      d   0.0043    0.9 -0.0154 0.0239  False
#      c      d   0.0041    0.9 -0.0156 0.0237  False
# ---------------------------------------------------

# %%
tukey = pairwise_tukeyhsd(endog = vbb.data.chc_simple_error.values.tolist() 
                          + vbb.data.chr_simple_error.values.tolist() 
                        #  + nvs.data.chc_simple_error.values.tolist() 
                          + vbb.data.mb_simple_error.values.tolist(),
                          groups = np.repeat(['a', 'b', 'c'], repeats=100),
                          alpha = 0.05)
print(tukey)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2   meandiff   p-adj     lower        upper     reject
# ------------------------------------------------------------------
#      a      b    2544.2324 0.7468   -6082.9805   11171.4454  False
#      a      c  -338483.517  0.001   -347110.73 -329856.3041   True
#      b      c -341027.7495  0.001 -349654.9624 -332400.5365   True
# ------------------------------------------------------------------

# %% [markdown]
# ## Sum of squares differences in node height

# %%
canvas = toyplot.Canvas(width=1200, height=1200)
ax0 = canvas.cartesian(grid=(4, 3, 0), label = "no-var-shallow")
mark0 = ax0.bars(np.histogram(nvs_ss.data.chr_relative_error.values), opacity = 0.25)
ax1 = canvas.cartesian(grid=(4, 3, 1), label = "no-var-root")
mark1 = ax1.bars(np.histogram(nvr_ss.data.chr_relative_error.values), opacity = 0.25)
ax2 = canvas.cartesian(grid=(4, 3, 2), label = "no-var-full")
mark2 = ax2.bars(np.histogram(nvb_ss.data.chr_relative_error.values), opacity = 0.25)
ax3 = canvas.cartesian(grid=(4, 3, 3), label = "vary-Ne-shallow")
mark3 = ax3.bars(np.histogram(vns_ss.data.chr_relative_error.values), opacity = 0.25)
ax4 = canvas.cartesian(grid=(4, 3, 4), label = "vary-Ne-root")
mark4 = ax4.bars(np.histogram(vnr_ss.data.chr_relative_error.values), opacity = 0.25)
ax5 = canvas.cartesian(grid=(4, 3, 5), label = "vary-Ne-full")
mark5 = ax5.bars(np.histogram(vnb_ss.data.chr_relative_error.values), opacity = 0.25)
ax6 = canvas.cartesian(grid=(4, 3, 6), label = "vary-g-shallow")
mark6 = ax6.bars(np.histogram(vgs_ss.data.chr_relative_error.values), opacity = 0.25)
ax7 = canvas.cartesian(grid=(4, 3, 7), label = "vary-g-root")
mark7 = ax7.bars(np.histogram(vgr_ss.data.chr_relative_error.values), opacity = 0.25)
ax8 = canvas.cartesian(grid=(4, 3, 8), label = "vary-g-full")
mark8 = ax8.bars(np.histogram(vgb_ss.data.chr_relative_error.values), opacity = 0.25)
ax9 = canvas.cartesian(grid=(4, 3, 9), label = "vary-Ne-g-shallow")
mark9 = ax9.bars(np.histogram(vbs_ss.data.chr_relative_error.values), opacity = 0.25)
ax10 = canvas.cartesian(grid=(4, 3, 10), label = "vary-Ne-g-root")
mark10 = ax10.bars(np.histogram(vbr_ss.data.chr_relative_error.values), opacity = 0.25)
ax11 = canvas.cartesian(grid=(4, 3, 11), label = "vary-Ne-g-full")
mark11 = ax11.bars(np.histogram(vbb_ss.data.chr_relative_error.values), opacity = 0.25)
# Out:
# <div class="toyplot" id="t353ed87ed3344df197504e1e92af7a3f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="1200.0px" id="t5573d4c303fe48a49663a97e3e4c408d" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1200.0 1200.0" width="1200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tb3eba079907c474dba82cfe4a2250af4"><clipPath id="t5c861da9a2bc4f7180b6fd4ec1ad0ea4"><rect height="220.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t5c861da9a2bc4f7180b6fd4ec1ad0ea4)"><g class="toyplot-mark-BarMagnitudes" id="ta7e7eda4526d4fc6bea9bf899eb45fbd" style="stroke:rgb(100%,100%,10
# ...

# %%
canvas = toyplot.Canvas(width=1200, height=1200)
locator = toyplot.locator.Extended(format="{:.3e}")
ax0 = canvas.cartesian(grid=(4, 3, 0), label = "no-var-shallow")
ax0.x.ticks.locator = locator
mark0 = ax0.bars(np.histogram(nvs_ss.data.mb_relative_error.values), opacity = 0.25)
ax1 = canvas.cartesian(grid=(4, 3, 1), label = "no-var-root")
ax1.x.ticks.locator = locator
mark1 = ax1.bars(np.histogram(nvr_ss.data.mb_relative_error.values), opacity = 0.25)
ax2 = canvas.cartesian(grid=(4, 3, 2), label = "no-var-full")
ax2.x.ticks.locator = locator
mark2 = ax2.bars(np.histogram(nvb_ss.data.mb_relative_error.values), opacity = 0.25)
ax3 = canvas.cartesian(grid=(4, 3, 3), label = "vary-Ne-shallow")
ax3.x.ticks.locator = locator
mark3 = ax3.bars(np.histogram(vns_ss.data.mb_relative_error.values), opacity = 0.25)
ax4 = canvas.cartesian(grid=(4, 3, 4), label = "vary-Ne-root")
ax4.x.ticks.locator = locator
mark4 = ax4.bars(np.histogram(vnr_ss.data.mb_relative_error.values), opacity = 0.25)
ax5 = canvas.cartesian(grid=(4, 3, 5), label = "vary-Ne-full")
ax5.x.ticks.locator = locator
mark5 = ax5.bars(np.histogram(vnb_ss.data.mb_relative_error.values), opacity = 0.25)
ax6 = canvas.cartesian(grid=(4, 3, 6), label = "vary-g-shallow")
ax6.x.ticks.locator = locator
mark6 = ax6.bars(np.histogram(vgs_ss.data.mb_relative_error.values), opacity = 0.25)
ax7 = canvas.cartesian(grid=(4, 3, 7), label = "vary-g-root")
ax7.x.ticks.locator = locator
mark7 = ax7.bars(np.histogram(vgr_ss.data.mb_relative_error.values), opacity = 0.25)
ax8 = canvas.cartesian(grid=(4, 3, 8), label = "vary-g-full")
ax8.x.ticks.locator = locator
mark8 = ax8.bars(np.histogram(vgb_ss.data.mb_relative_error.values), opacity = 0.25)
ax9 = canvas.cartesian(grid=(4, 3, 9), label = "vary-Ne-g-shallow")
ax9.x.ticks.locator = locator
mark9 = ax9.bars(np.histogram(vbs_ss.data.mb_relative_error.values), opacity = 0.25)
ax10 = canvas.cartesian(grid=(4, 3, 10), label = "vary-Ne-g-root")
ax10.x.ticks.locator = locator
mark10 = ax10.bars(np.histogram(vbr_ss.data.mb_relative_error.values), opacity = 0.25)
ax11 = canvas.cartesian(grid=(4, 3, 11), label = "vary-Ne-g-full")
ax11.x.ticks.locator = locator
mark11 = ax11.bars(np.histogram(vbb_ss.data.mb_relative_error.values), opacity = 0.25)
# Out:
# <div class="toyplot" id="t5a43a0f633f848e69e2f7fec90b96e8b" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="1200.0px" id="t584359d5103640498d6622ff9d592e40" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1200.0 1200.0" width="1200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t9b76af3ef5e44853afed5aaf4407d363"><clipPath id="t9dbdc9751b1d44688792c1267a0b1a70"><rect height="220.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t9dbdc9751b1d44688792c1267a0b1a70)"><g class="toyplot-mark-BarMagnitudes" id="tc7b12f4041d94e3b90d554950c6b071c" style="stroke:rgb(100%,100%,10
# ...

# %%
canvas = toyplot.Canvas(width=1200, height=1200)
locator = toyplot.locator.Extended(format="{:.3e}")
ax0 = canvas.cartesian(grid=(4, 3, 0), label = "no-var-shallow")
ax0.x.ticks.locator = locator
mark0 = ax0.bars(np.histogram(nvs_ss.data.chc_relative_error.values), opacity = 0.25)
mark0 = ax0.bars(np.histogram(nvs_ss.data.chr_relative_error.values), opacity = 0.25)
mark0 = ax0.bars(np.histogram(nvs_ss.data.mb_relative_error.values), opacity = 0.25)
ax1 = canvas.cartesian(grid=(4, 3, 1), label = "no-var-root")
ax1.x.ticks.locator = locator
mark1 = ax1.bars(np.histogram(nvr_ss.data.chc_relative_error.values), opacity = 0.25)
mark1 = ax1.bars(np.histogram(nvr_ss.data.chr_relative_error.values), opacity = 0.25)
mark1 = ax1.bars(np.histogram(nvr_ss.data.mb_relative_error.values), opacity = 0.25)
ax2 = canvas.cartesian(grid=(4, 3, 2), label = "no-var-full")
ax2.x.ticks.locator = locator
mark2 = ax2.bars(np.histogram(nvb_ss.data.chc_relative_error.values), opacity = 0.25)
mark2 = ax2.bars(np.histogram(nvb_ss.data.chr_relative_error.values), opacity = 0.25)
mark2 = ax2.bars(np.histogram(nvb_ss.data.mb_relative_error.values), opacity = 0.25)
ax3 = canvas.cartesian(grid=(4, 3, 3), label = "vary-Ne-shallow")
ax3.x.ticks.locator = locator
mark3 = ax3.bars(np.histogram(vns_ss.data.chc_relative_error.values), opacity = 0.25)
mark3 = ax3.bars(np.histogram(vns_ss.data.chr_relative_error.values), opacity = 0.25)
mark3 = ax3.bars(np.histogram(vns_ss.data.mb_relative_error.values), opacity = 0.25)
ax4 = canvas.cartesian(grid=(4, 3, 4), label = "vary-Ne-root")
ax4.x.ticks.locator = locator
mark4 = ax4.bars(np.histogram(vnr_ss.data.chc_relative_error.values), opacity = 0.25)
mark4 = ax4.bars(np.histogram(vnr_ss.data.chr_relative_error.values), opacity = 0.25)
mark4 = ax4.bars(np.histogram(vnr_ss.data.mb_relative_error.values), opacity = 0.25)
ax5 = canvas.cartesian(grid=(4, 3, 5), label = "vary-Ne-full")
ax5.x.ticks.locator = locator
mark5 = ax5.bars(np.histogram(vnb_ss.data.chc_relative_error.values), opacity = 0.25)
mark5 = ax5.bars(np.histogram(vnb_ss.data.chr_relative_error.values), opacity = 0.25)
mark5 = ax5.bars(np.histogram(vnb_ss.data.mb_relative_error.values), opacity = 0.25)
ax6 = canvas.cartesian(grid=(4, 3, 6), label = "vary-g-shallow")
ax6.x.ticks.locator = locator
mark6 = ax6.bars(np.histogram(vgs_ss.data.chc_relative_error.values), opacity = 0.25)
mark6 = ax6.bars(np.histogram(vgs_ss.data.chr_relative_error.values), opacity = 0.25)
mark6 = ax6.bars(np.histogram(vgs_ss.data.mb_relative_error.values), opacity = 0.25)
ax7 = canvas.cartesian(grid=(4, 3, 7), label = "vary-g-root")
ax7.x.ticks.locator = locator
mark7 = ax7.bars(np.histogram(vgr_ss.data.chc_relative_error.values), opacity = 0.25)
mark7 = ax7.bars(np.histogram(vgr_ss.data.chr_relative_error.values), opacity = 0.25)
mark7 = ax7.bars(np.histogram(vgr_ss.data.mb_relative_error.values), opacity = 0.25)
ax8 = canvas.cartesian(grid=(4, 3, 8), label = "vary-g-full")
ax8.x.ticks.locator = locator
mark8 = ax8.bars(np.histogram(vgb_ss.data.chc_relative_error.values), opacity = 0.25)
mark8 = ax8.bars(np.histogram(vgb_ss.data.chr_relative_error.values), opacity = 0.25)
mark8 = ax8.bars(np.histogram(vgb_ss.data.mb_relative_error.values), opacity = 0.25)
ax9 = canvas.cartesian(grid=(4, 3, 9), label = "vary-Ne-g-shallow")
ax9.x.ticks.locator = locator
mark9 = ax9.bars(np.histogram(vbs_ss.data.chc_relative_error.values), opacity = 0.25)
mark9 = ax9.bars(np.histogram(vbs_ss.data.chr_relative_error.values), opacity = 0.25)
mark9 = ax9.bars(np.histogram(vbs_ss.data.mb_relative_error.values), opacity = 0.25)
ax10 = canvas.cartesian(grid=(4, 3, 10), label = "vary-Ne--g-root")
ax10.x.ticks.locator = locator
mark10 = ax10.bars(np.histogram(vbr_ss.data.chc_relative_error.values), opacity = 0.25)
mark10 = ax10.bars(np.histogram(vbr_ss.data.chr_relative_error.values), opacity = 0.25)
mark10 = ax10.bars(np.histogram(vbr_ss.data.mb_relative_error.values), opacity = 0.25)
ax11 = canvas.cartesian(grid=(4, 3, 11), label = "vary-Ne-g-full")
ax11.x.ticks.locator = locator
mark11 = ax11.bars(np.histogram(vbb_ss.data.chc_relative_error.values), opacity = 0.25)
mark11 = ax11.bars(np.histogram(vbb_ss.data.chr_relative_error.values), opacity = 0.25)
mark11 = ax11.bars(np.histogram(vbb_ss.data.mb_relative_error.values), opacity = 0.25)
# Out:
# <div class="toyplot" id="t0e94b2022c124fbeadca84bb5de18763" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="1200.0px" id="t530f6aa86f034946a83365f38b4c2a7b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1200.0 1200.0" width="1200.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t038477453fbe4cb5b8729eeafc8b0d4d"><clipPath id="tf136dab69288420eb8732fdbf8c21ff7"><rect height="220.0" width="320.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tf136dab69288420eb8732fdbf8c21ff7)"><g class="toyplot-mark-BarMagnitudes" id="t516db84fd9ac4d64aa1059fb26d8f614" style="stroke:rgb(100%,100%,10
# ...

# %% [markdown]
# other stuff for later

# %%
import matplotlib.pyplot as plt

# %%
bins = np.linspace(1e15, 7e15, 100)
plt.rc('font', size = 36)

fig, axs = plt.subplots(4, 3, figsize = (50, 50))
axs[0, 0].hist(nvs.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[0, 0].set_title("no-var-shallow")
axs[0, 1].hist(nvr.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[0, 1].set_title("no-var-root")
axs[0, 2].hist(nvb.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[0, 2].set_title("no-var-full")
axs[1, 0].hist(vns.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[1, 0].set_title("vary-Ne-shallow")
axs[1, 1].hist(vnr.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[1, 1].set_title("vary-Ne-root")
axs[1, 2].hist(vnb.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[1, 2].set_title("vary-Ne-full")
axs[2, 0].hist(vgs.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[2, 0].set_title("vary-g-shallow")
axs[2, 1].hist(vgr.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[2, 1].set_title("vary-g-root")
axs[2, 2].hist(vgb.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[2, 2].set_title("vary-g-full")
axs[3, 0].hist(vbs.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[3, 0].set_title("vary-Ne-g-shallow")
axs[3, 1].hist(vbr.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[3, 1].set_title("vary-Ne-g-root")
axs[3, 2].hist(vbb.data["chc_simple_error"], bins, facecolor='b', alpha=0.5);
axs[3, 2].set_title("vary-Ne-g-full")
# Out:
# Text(0.5, 1.0, 'vary-Ne-g-full')

# %%
fig.savefig("/home/henry/phylo-timescale/svg/simple_error_panel.svg")

# %%
bins = np.linspace(1e15, 7e15, 100)
plt.rc('font', size = 36)

fig, axs = plt.subplots(4, 3, figsize = (50, 50))
axs[0, 0].hist(nvs.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[0, 0].set_title("no-var-shallow")
axs[0, 1].hist(nvr.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[0, 1].set_title("no-var-root")
axs[0, 2].hist(nvb.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[0, 2].set_title("no-var-full")
axs[1, 0].hist(vns.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[1, 0].set_title("vary-Ne-shallow")
axs[1, 1].hist(vnr.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[1, 1].set_title("vary-Ne-root")
axs[1, 2].hist(vnb.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[1, 2].set_title("vary-Ne-full")
axs[2, 0].hist(vgs.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[2, 0].set_title("vary-g-shallow")
axs[2, 1].hist(vgr.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[2, 1].set_title("vary-g-root")
axs[2, 2].hist(vgb.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[2, 2].set_title("vary-g-full")
axs[3, 0].hist(vbs.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[3, 0].set_title("vary-Ne-g-shallow")
axs[3, 1].hist(vbr.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[3, 1].set_title("vary-Ne-g-root")
axs[3, 2].hist(vbb.data["chc_relative_error"], bins, facecolor='b', alpha=0.5);
axs[3, 2].set_title("vary-Ne-g-full")
# Out:
# Text(0.5, 1.0, 'vary-Ne-g-full')

# %% [markdown]
# ## ipcoal figures to show rate variation influence

# %%
# generate a random tree with 8 tips and height of 1M generations
tree_ne = toytree.rtree.unittree(8, treeheight=1e6, seed=123)
# draw tree showing idx labels
tree_ne.draw(tree_style='p');
# Out:
# <div class="toyplot" id="t675e9424e9ad4a22a4b70bac46d1ce99" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="t21124d28319e42c292d4e74b5c986edc" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tf7724fe0c7b942c8b5ff80f2a065a13d"><clipPath id="t1980a67504f74e188a48bb9394e8ac0f"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t1980a67504f74e188a48bb9394e8ac0f)"><g class="toytree-mark-Toytree" id="t28a5b57fe7f34e558f1e89fd35fc68fd"><g class="toytree-Edges" style="fill:non
# ...

# %%
base = toytree.rtree.unittree(8, treeheight=1e6, seed=123)
c0, a0, m0 = base.draw(tree_style='p');
# Out:
# <div class="toyplot" id="t6ebc31049da9452e8719de5de63f3eae" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="tabc085088bda41ce87f6ee3210dc216e" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tc5fbab88265545158bcdb1c5ea55a1ac"><clipPath id="t365cfb66c2ca4eb0a219c449809186d3"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t365cfb66c2ca4eb0a219c449809186d3)"><g class="toytree-mark-Toytree" id="tb7e064a029044610aaedbeaf5361d06e"><g class="toytree-Edges" style="fill:non
# ...

# %%
toyplot.svg.render(c0, "/home/henry/phylo-timescale/svg/base_ipcoal.svg")

# %%
rng = np.random.default_rng(123)

# Divide edge lengths (absolute time) by generation time to 
# convert tree to units of number of generations. Tree is 
# now likely to be non-ultrametric.
gdict = dict(zip(range(tree_ne.nnodes), rng.uniform(1, 1, tree_ne.nnodes)))
tree_ne = tree_ne.set_node_values("g", values=gdict)
tree_ne = tree_ne.set_node_values(
                "dist", 
                {i: j.dist / j.g for (i, j) in tree_ne.idx_dict.items()}
)
tree_ne.draw(tree_style='p');
# Out:
# <div class="toyplot" id="t6eba2173350e4c2384e2923599975d59" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="t8feae3f7aa3f48d28be6c53a2cb7251e" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t5e0814c3afb149688ef322b6d2b396c4"><clipPath id="ta2b7886b94d64785bf8e0ffc5ab7128c"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#ta2b7886b94d64785bf8e0ffc5ab7128c)"><g class="toytree-mark-Toytree" id="t5585d054aa4743aea0449bd77de8706f"><g class="toytree-Edges" style="fill:non
# ...

# %%
c1, a1, m1 = tree_ne.draw(tree_style='p');
# Out:
# <div class="toyplot" id="t728c7b71460748fa9af921edcc30d0f6" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="td98c07a438c74273b0d8fbbe77a19922" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tc3779becb5214a2f8dc5b3e9533a9f69"><clipPath id="tc7c513f946794ef68bbbabfe9868b5f1"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#tc7c513f946794ef68bbbabfe9868b5f1)"><g class="toytree-mark-Toytree" id="t874ab30eea3042f9a9ded27fea8ffa0a"><g class="toytree-Edges" style="fill:non
# ...

# %%
toyplot.svg.render(c1, "/home/henry/phylo-timescale/svg/ne_ipcoal.svg")

# %%
nedict = dict(zip(range(tree_ne.nnodes), rng.uniform(1e5, 1e6, tree_ne.nnodes)))
tree_ne = tree_ne.set_node_values("Ne", values=nedict)

# %%
model = ipcoal.Model(tree_ne, seed=123)
model.sim_loci(10, 500)

# %%
kwargs = {
    "ts": "c",
    "tip_labels": True,
    #"shared_axis": True,
    "width": 1000,
    "height": 500,
    "node_sizes": 6,
}

ne_gen = toytree.mtree(model.df.genealogy.sample(10))
c3, a3, m3 = ne_gen.draw(2, 5, **kwargs);
# Out:
# <div class="toyplot" id="t7738e5fd9b02465aa656afbb90cea5c5" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="500.0px" id="te27ebbd652c54151b9321a5bac62e432" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t23b0605058ce462d981e8f884c98f1a0"><clipPath id="t4150f2f6df09455c9b8cb0214c8cfdd9"><rect height="220.0" width="170.0" x="15.0" y="15.0"></rect></clipPath><g clip-path="url(#t4150f2f6df09455c9b8cb0214c8cfdd9)"><g class="toytree-mark-Toytree" id="tf4d16f0876c549009c5800e1d6c7079a"><g class="toytree-Edges" style="fill:n
# ...

# %%
toyplot.svg.render(c3, "/home/henry/phylo-timescale/svg/ne_array.svg")

# %%
# generate a random tree with 8 tips and height of 1M generations
tree_g = toytree.rtree.unittree(8, treeheight=1e6, seed=123)
# draw tree showing idx labels
tree_g.draw(tree_style='p');
# Out:
# <div class="toyplot" id="t08204a82122c458f9c2f3f41841e959d" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="tbc31c2ce1dec4706aede1c4b780413be" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t406c7caade5747188a82818905010abf"><clipPath id="t2335b172d6d04bfbbfcba005d7464619"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t2335b172d6d04bfbbfcba005d7464619)"><g class="toytree-mark-Toytree" id="t4f7ed1dfe8104506898cd6506f9cdb5c"><g class="toytree-Edges" style="fill:non
# ...

# %%
gdict = dict(zip(range(tree_ne.nnodes), rng.uniform(0.5, 5, tree_g.nnodes)))
tree_g = tree_g.set_node_values("g", values=gdict)
tree_g = tree_g.set_node_values(
                "dist", 
                {i: j.dist / j.g for (i, j) in tree_g.idx_dict.items()}
)
tree_g.draw(tree_style='p');
# Out:
# <div class="toyplot" id="t2365b0544de74230ab87e977e1f54d9f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="tdb09aa8fd9b240d08fbb021efb599dc1" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tffc2f9f0326541d49d614c0e9303fc1d"><clipPath id="t1f9905e9b4764cb48630840e91d168ad"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t1f9905e9b4764cb48630840e91d168ad)"><g class="toytree-mark-Toytree" id="teab906f4ac224da68853a648328006cd"><g class="toytree-Edges" style="fill:non
# ...

# %%
c2, a2, m2 = tree_g.draw(tree_style='p');
# Out:
# <div class="toyplot" id="t99c54b1ad29941dbab45acd6c292eb93" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="t5a86bbc3d61548b4acd41ea758ee84cb" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t7e89098564d745dd84111c728c21710f"><clipPath id="t984e288d6bfd4112b815c579e68f6b6f"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t984e288d6bfd4112b815c579e68f6b6f)"><g class="toytree-mark-Toytree" id="t5b99e02955fc41cca59f3e554d6fe857"><g class="toytree-Edges" style="fill:non
# ...

# %%
toyplot.svg.render(c2, "/home/henry/phylo-timescale/svg/g_ipcoal.svg")

# %%
model_g = ipcoal.Model(tree_g, seed=123)
model_g.sim_loci(10, 500)

# %%
g_gen = toytree.mtree(model_g.df.genealogy.sample(10))
c4, a4, m4 = g_gen.draw(2, 5, **kwargs);
# Out:
# <div class="toyplot" id="t3ee30efcfab34f14ab4e5766dee8c7d7" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="500.0px" id="tf1dfc44e330d45bbaf9ff3c8fbee14f7" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1000.0 500.0" width="1000.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t41cde945fc3c45429c92dcbbbcb51a1a"><clipPath id="t309f60e374174f27a9f8ab65d9362d15"><rect height="220.0" width="170.0" x="15.0" y="15.0"></rect></clipPath><g clip-path="url(#t309f60e374174f27a9f8ab65d9362d15)"><g class="toytree-mark-Toytree" id="t4acbe513e26b490aaed50116822f2d7b"><g class="toytree-Edges" style="fill:n
# ...

# %%
toyplot.svg.render(c4, "/home/henry/phylo-timescale/svg/g_array.svg")

# %%
import toyplot.png

# %%
toyplot.png.render(c0, "/home/henry/phylo-timescale/svg/base_ipcoal.png")
toyplot.png.render(c1, "/home/henry/phylo-timescale/svg/ne_ipcoal.png")
toyplot.png.render(c2, "/home/henry/phylo-timescale/svg/g_ipcoal.png")
toyplot.png.render(c3, "/home/henry/phylo-timescale/svg/ne_array.png")
toyplot.png.render(c4, "/home/henry/phylo-timescale/svg/g_array.png")

# %%
def rmse(predictions, targets):
    differences = predictions - targets                       #the DIFFERENCEs.
    differences_squared = differences ** 2                    #the SQUAREs of ^
    mean_of_differences_squared = differences_squared.mean()  #the MEAN of ^
    rmse_val = np.sqrt(mean_of_differences_squared)           #ROOT of ^
    return rmse_val                                           #get the ^
