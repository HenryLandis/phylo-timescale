.9 L 224.5 100.9 L 224.5 110.7" id="71,65"></path><path d="M 192.9 100.9 L 161.3 100.9 L 161.3 110.7" id="71,64"></path><path d="M 651.8 110.7 L 639.9 110.7 L 639.9 120.6" id="70,63"></path><path d="M 411.4 110.7 L 396.6 110.7 L 396.6 120.6" id="67,62"></path><path d="M 285.8 110.7 L 271.9 110.7 L 271.9 120.6" id="66,61"></path><path d="M 224.5 110.7 L 212.6 110.7 L 212.6 120.6" id="65,60"></path><path d="M 161.3 110.7 L 180.9 110.7 L 180.9 120.6" id="64,59"></path><path d="M 161.3 110.7 L 141.6 110.7 L 141.6 120.6" id="64,58"></path><path d="M 396.6 120.6 L 382.7 120.6 L 382.7 130.5" id="62,57"></path><path d="M 271.9 120.6 L 260.1 120.6 L 260.1 130.5" id="61,56"></path><path d="M 141.6 120.6 L 126.0 120.6 L 126.0 130.5"  ...

# %%
# Copy the tree three times for testing variation in Ne, g and both.
realtree_vary_ne = realtree.copy()
realtree_vary_g = realtree.copy()
realtree_vary_both = realtree.copy()

# %%
# Create a dictionary of random Ne values within an interval and set onto tree.
np.random.seed(0)
dict_ne = {i.name : np.random.randint(5e5, 5e6) for i in realtree_vary_ne.get_feature_dict()}
realtree_vary_ne = realtree_vary_ne.set_node_values("Ne", dict_ne)

# %%
# Create a dictionary of g values from a normal distribution and set onto tree.
np.random.seed(1)
dict_g = {i.name : np.random.normal(1, 0.2) for i in realtree_vary_g.get_feature_dict()}
realtree_vary_g = realtree_vary_g.set_node_values("g", dict_g)

# %%
# Use the variation in Ne and g already generated simultaneously for the last tree.
realtree_vary_both = realtree_vary_both.set_node_values("Ne", dict_ne)
realtree_vary_both = realtree_vary_both.set_node_values("g", dict_g)

# %%
# For the trees where Ne does not vary, set a value of Ne = 1e6 across the tree.
dict_ne_for_real = {i.name : 1e6 for i in realtree.get_feature_dict()}
dict_ne_for_g = {i.name : 1e6 for i in realtree_vary_ne.get_feature_dict()}
realtree = realtree.set_node_values("Ne", dict_ne_for_real)
realtree_vary_g = realtree_vary_g.set_node_values("Ne", dict_ne_for_g)

# %%
# For the trees where g does not vary, set a value of g = 1 across the tree.
dict_g_for_real = {i.name : 1 for i in realtree.get_feature_dict()}
dict_g_for_ne = {i.name : 1 for i in realtree_vary_ne.get_feature_dict()}
realtree = realtree.set_node_values("g", dict_g_for_real)
realtree_vary_ne = realtree_vary_ne.set_node_values("g", dict_g_for_ne)

# %%
# To simulate chloroplast, copy the base tree and divide Ne values by 4 across all tips.
realtree_chp = realtree.copy()
dict_ne_for_chp = {i.name : (1e6 / 4) for i in realtree_chp.get_feature_dict()}
dict_g_for_chp = {i.name : 1 for i in realtree_chp.get_feature_dict()}
realtree_chp = realtree_chp.set_node_values("Ne", dict_ne_for_chp)
realtree_chp = realtree_chp.set_node_values("g", dict_g_for_chp)

# %%
# Divide edge lengths (absolute time) by generation time to get units of generations for each tree.
trealtree = realtree.set_node_values(
    "dist",
    {i.name: i.dist / i.g for i in realtree.get_feature_dict()}
)
trealtree_vary_ne = realtree_vary_ne.set_node_values(
    "dist",
    {i.name: i.dist / i.g for i in realtree_vary_ne.get_feature_dict()}
)
trealtree_vary_g = realtree_vary_g.set_node_values(
    "dist",
    {i.name: i.dist / i.g for i in realtree_vary_g.get_feature_dict()}
)
trealtree_vary_both = realtree_vary_both.set_node_values(
    "dist",
    {i.name: i.dist / i.g for i in realt
" id="71,64"></path><path d="M 651.8 110.7 L 639.9 110.7 L 639.9 120.6" id="70,63"></path><path d="M 411.4 110.7 L 396.6 110.7 L 396.6 120.6" id="67,62"></path><path d="M 285.8 110.7 L 271.9 110.7 L 271.9 120.6" id="66,61"></path><path d="M 224.5 110.7 L 212.6 110.7 L 212.6 120.6" id="65,60"></path><path d="M 161.3 110.7 L 180.9 110.7 L 180.9 120.6" id="64,59"></path><path d="M 161.3 110.7 L 141.6 110.7 L 141.6 120.6" id="64,58"></path><path d="M 396.6 120.6 L 382.7 120.6 L 382.7 130.5" id="62,57"></path><path d="M 271.9 120.6 L 260.1 120.6 L 260.1 130.5" id="61,56"></path><path d="M 141.6 120.6 L 126.0 120.6 L 126.0 130.5"  ...

# %%
# Write the five trees to be used in ipcoal sims to Newick files.
trealtree.write("/home/henry/phylo-timescale/newick/realtree.tre")
trealtree_vary_ne.write("/home/henry/phylo-timescale/newick/realtree_vary_ne.tre")
trealtree_vary_g.write("/home/henry/phylo-timescale/newick/realtree_vary_g.tre")
trealtree_vary_both.write("/home/henry/phylo-timescale/newick/realtree_vary_both.tre")
trealtree_chp.write("/home/henry/phylo-timescale/newick/realtree_chp.tre")

# %%
# Create model objects for each tree.
model_real = ipcoal.Model(trealtree, nsamples = 2, seed = 234)
model_ne = ipcoal.Model(trealtree_vary_ne, nsamples = 2, seed = 345)
model_g = ipcoal.Model(trealtree_vary_g, nsamples = 2, seed = 456)
model_both = ipcoal.Model(trealtree_vary_both, nsamples = 2, seed = 567)
model_chp = ipcoal.Model(trealtree_chp, nsamples = 2, recomb = 0, seed = 678)

# %%
# Simulate sequence data: 2000 loci of 500 bp.  For the chloroplast, instead do 1 locus of 2000 bp.
model_real.sim_loci(2000, 500)
model_ne.sim_loci(2000, 500)
model_g.sim_loci(2000, 500)
model_both.sim_loci(2000, 500)

# %%
model_chp.sim_loci(1, 2000)

# %%
# Write the dataframe results of the model objects to CSV files.
model_real.df.to_csv("/home/henry/phylo-timescale/ipcoal-df-csv/realtree.csv")
model_ne.df.to_csv("/home/henry/phylo-timescale/ipcoal-df-csv/realtree_vary_ne.csv")
model_g.df.to_csv("/home/henry/phylo-timescale/ipcoal-df-csv/realtree_vary_g.csv")
model_both.df.to_csv("/home/henry/phylo-timescale/ipcoal-df-csv/realtree_vary_both.csv")
model_chp.df.to_csv("/home/henry/phylo-timescale/ipcoal-df-csv/realtree_chp.csv")

# %%
# Write small matrices to files.
model_real.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_real_small_haploid.phy")
model_ne.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_ne_small_haploid.phy")
model_g.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_g_small_haploid.phy")
model_both.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_both_small_haploid.phy")
model_chp.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_chp_small_haploid.phy")

model_real.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                                  name = "model_real_small_diploid.phy")
model_ne.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                                name = "model_ne_small_diploid.phy")
model_g.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                               name = "model_g_small_diploid.phy")
model_both.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                                  name = "model_both_small_diploid.phy")
model_chp.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                                 name = "model_chp_small_diploid.phy")

model_real.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_real_small_haploid_loci")
model_ne.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_ne_small_haploid_loci")
model_g.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_g_small_haploid_loci")
model_both.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_both_small_haploid_loci")
model_chp.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_chp_small_haploid_loci")

model_real.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True, 
                              name = "model_real_small_diploid_loci")
model_ne.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                            name = "model_ne_small_diploid_loci")
model_g.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                           name = "model_g_small_diploid_loci")
model_both.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                              name = "model_both_small_diploid_loci")
model_chp.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                             name = "model_chp_small_diploid_loci")

model_real.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_real_small_haploid_snps")
model_ne.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_ne_small_haploid_snps")
model_g.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_g_small_haploid_snps")
model_both.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_both_small_haploid_snps")
model_chp.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_chp_small_haploid_snps")

model_real.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                              name = "model_real_small_diploid_snps")
model_ne.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                            name = "model_ne_small_diploid_snps")
model_g.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                           name = "model_g_small_diploid_snps")
model_both.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                              name = "model_both_small_diploid_snps")
model_chp.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                             name = "model_chp_small_diploid_snps")
# Out:
# wrote concat locus (100 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_real_small_haploid.phy
# wrote concat locus (100 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_ne_small_haploid.phy
# wrote concat locus (100 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_g_small_haploid.phy
# wrote concat locus (100 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_both_small_haploid.phy
# wrote concat locus (100 x 2000bp) to /home/henry/phylo-timescale/phylip-files/model_chp_small_haploid.phy
# wrote concat locus (50 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_real_small_diploid.phy
# wrote concat locus (50 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_ne_small_diploid.phy
# wrote concat locus (50 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_g_small_diploid.phy
# wrote concat locus (50 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_both_small_diploid.phy
# wrote concat locus (50 x 2000bp) to /home/henry/phylo-timescale/phylip-files/model_chp_small_diploid.phy
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_real_small_haploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_ne_small_haploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_g_small_haploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_both_small_haploid_loci.seqs.hdf5
# wrote 1 loci to /home/henry/phylo-timescale/alignments/model_chp_small_haploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_real_small_diploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_ne_small_diploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_g_small_diploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_both_small_diploid_loci.seqs.hdf5
# wrote 1 loci to /home/henry/phylo-timescale/alignments/model_chp_small_diploid_loci.seqs.hdf5
# wrote 999898 SNPs to /home/henry/phylo-timescale/alignments/model_real_small_haploid_snps.snps.hdf5
# wrote 999986 SNPs to /home/henry/phylo-timescale/alignments/model_ne_small_haploid_snps.snps.hdf5
# wrote 999929 SNPs to /home/henry/phylo-timescale/alignments/model_g_small_haploid_snps.snps.hdf5
# wrote 999986 SNPs to /home/henry/phylo-timescale/alignments/model_both_small_haploid_snps.snps.hdf5
# wrote 1999 SNPs to /home/henry/phylo-timescale/alignments/model_chp_small_haploid_snps.snps.hdf5
# wrote 999898 SNPs to /home/henry/phylo-timescale/alignments/model_real_small_diploid_snps.snps.hdf5
# wrote 999986 SNPs to /home/henry/phylo-timescale/alignments/model_ne_small_diploid_snps.snps.hdf5
# wrote 999929 SNPs to /home/henry/phylo-timescale/alignments/model_g_small_diploid_snps.snps.hdf5
# wrote 999986 SNPs to /home/henry/phylo-timescale/alignments/model_both_small_diploid_snps.snps.hdf5
# wrote 1999 SNPs to /home/henry/phylo-timescale/alignments/model_chp_small_diploid_snps.snps.hdf5

# %%
# Write large matrices to files.
model_real.apply_missing_mask(coverage = 0.5, coverage_type = "site")
model_ne.apply_missing_mask(coverage = 0.5, coverage_type = "site")
model_g.apply_missing_mask(coverage = 0.5, coverage_type = "site")
model_both.apply_missing_mask(coverage = 0.5, coverage_type = "site")
model_chp.apply_missing_mask(coverage = 0.5, coverage_type = "site")

model_real.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_real_large_haploid.phy")
model_ne.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_ne_large_haploid.phy")
model_g.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_g_large_haploid.phy")
model_both.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_both_large_haploid.phy")
model_chp.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", name = "model_chp_large_haploid.phy")

model_real.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                                  name = "model_real_large_diploid.phy")
model_ne.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                                name = "model_ne_large_diploid.phy")
model_g.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                               name = "model_g_large_diploid.phy")
model_both.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                                  name = "model_both_large_diploid.phy")
model_chp.write_concat_to_phylip(outdir = "/home/henry/phylo-timescale/phylip-files", diploid = True,
                                 name = "model_chp_large_diploid.phy")

model_real.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_real_large_haploid_loci")
model_ne.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_ne_large_haploid_loci")
model_g.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_g_large_haploid_loci")
model_both.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_both_large_haploid_loci")
model_chp.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_chp_large_haploid_loci")

model_real.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                              name = "model_real_large_diploid_loci")
model_ne.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True, 
                            name = "model_ne_large_diploid_loci")
model_g.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                           name = "model_g_large_diploid_loci")
model_both.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                              name = "model_both_large_diploid_loci")
model_chp.write_loci_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                             name = "model_chp_large_diploid_loci")

model_real.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_real_large_haploid_snps")
model_ne.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_ne_large_haploid_snps")
model_g.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_g_large_haploid_snps")
model_both.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_both_large_haploid_snps")
model_chp.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", name = "model_chp_large_haploid_snps")

model_real.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                              name = "model_real_large_diploid_snps")
model_ne.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                            name = "model_ne_large_diploid_snps")
model_g.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                           name = "model_g_large_diploid_snps")
model_both.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                              name = "model_both_large_diploid_snps")
model_chp.write_snps_to_hdf5(outdir = "/home/henry/phylo-timescale/alignments", diploid = True,
                             name = "model_chp_large_diploid_snps")
# Out:
# wrote concat locus (100 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_real_large_haploid.phy
# wrote concat locus (100 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_ne_large_haploid.phy
# wrote concat locus (100 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_g_large_haploid.phy
# wrote concat locus (100 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_both_large_haploid.phy
# wrote concat locus (100 x 2000bp) to /home/henry/phylo-timescale/phylip-files/model_chp_large_haploid.phy
# wrote concat locus (50 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_real_large_diploid.phy
# wrote concat locus (50 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_ne_large_diploid.phy
# wrote concat locus (50 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_g_large_diploid.phy
# wrote concat locus (50 x 1000000bp) to /home/henry/phylo-timescale/phylip-files/model_both_large_diploid.phy
# wrote concat locus (50 x 2000bp) to /home/henry/phylo-timescale/phylip-files/model_chp_large_diploid.phy
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_real_large_haploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_ne_large_haploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_g_large_haploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_both_large_haploid_loci.seqs.hdf5
# wrote 1 loci to /home/henry/phylo-timescale/alignments/model_chp_large_haploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_real_large_diploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_ne_large_diploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_g_large_diploid_loci.seqs.hdf5
# wrote 2000 loci to /home/henry/phylo-timescale/alignments/model_both_large_diploid_loci.seqs.hdf5
# wrote 1 loci to /home/henry/phylo-timescale/alignments/model_chp_large_diploid_loci.seqs.hdf5
# wrote 998564 SNPs to /home/henry/phylo-timescale/alignments/model_real_large_haploid_snps.snps.hdf5
# wrote 999281 SNPs to /home/henry/phylo-timescale/alignments/model_ne_large_haploid_snps.snps.hdf5
# wrote 998732 SNPs to /home/henry/phylo-timescale/alignments/model_g_large_haploid_snps.snps.hdf5
# wrote 999388 SNPs to /home/henry/phylo-timescale/alignments/model_both_large_haploid_snps.snps.hdf5
# wrote 1994 SNPs to /home/henry/phylo-timescale/alignments/model_chp_large_haploid_snps.snps.hdf5
# wrote 998564 SNPs to /home/henry/phylo-timescale/alignments/model_real_large_diploid_snps.snps.hdf5
# wrote 999281 SNPs to /home/henry/phylo-timescale/alignments/model_ne_large_diploid_snps.snps.hdf5
# wrote 998732 SNPs to /home/henry/phylo-timescale/alignments/model_g_large_diploid_snps.snps.hdf5
# wrote 999388 SNPs to /home/henry/phylo-timescale/alignments/model_both_large_diploid_snps.snps.hdf5
# wrote 1994 SNPs to /home/henry/phylo-timescale/alignments/model_chp_large_diploid_snps.snps.hdf5
