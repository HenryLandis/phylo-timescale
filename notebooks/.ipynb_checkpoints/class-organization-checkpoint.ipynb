# %%
import toytree
import pandas as pd
import numpy as np
import ipcoal
import ipyrad.analysis as ipa
import tempfile
import subprocess

# %%
tre = toytree.rtree.unittree(12, treeheight = 10e6, seed = 102)
tree = tre.write("/home/henry/phylo-timescale/classtest/tree.tre")

ttree = toytree.tree("/home/henry/phylo-timescale/classtest/tree.tre")
ttree.draw(node_labels="idx", node_sizes=12);
# Out:
# <div class="toyplot" id="ta97168f5f4c642bebc40af177a48e9dd" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="275.0px" id="ta155095b62084dae81dcb4d8ec7adeed" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 265.0 275.0" width="265.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t98eb0833825e4be2a33e5a5f252d1d0f"><clipPath id="t2ee97d5e979a4aa98e83b91983590a7d"><rect height="215.0" width="205.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t2ee97d5e979a4aa98e83b91983590a7d)"><g class="toytree-mark-Toytree" id="t5481ece7320a42db9997491d9c3c2331"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 50.0 114.2 L 50.0 74.1 L 73.2 74.1" id="22,21"></path><path d="M 50.0 114.2 L 50.0 154.4 L 73.2 154.4" id="22,20"></path><path d="M 73.2 74.1 L 73.2 87.1 L 96.5 87.1" id="21,19"></path><path d="M 73.2 154.4 L 73.2 137.5 L 96.5 137.5" id="20,18"></path><path d="M 73.2 154.4 L 73.2 171.4 L 96.5 171.4" id="20,17"></path><path d="M 96.5 87.1 L 96.5 99.3 L 119.7 99.3" id="19,16"></path><path d="M 96.5 171.4 L 96.5 184.4 L 119.7 184.4" id="17,15"></path><path d="M 119.7 99.3 L 119.7 109.7 L 142.9 109.7" id="16,14"></path><path d="M 119.7 184.4 L 119.7 196.6 L 142.9 196.6" id="15,13"></path><path d="M 142.9 196.6 L 142.9 207.0 L 166.1 207.0" id="13,12"></path><path d="M 73.2 74.1 L 73.2 61.0 L 189.4 61.0" id="21,11"></path><path d="M 96.5 87.1 L 96.5 74.9 L 189.4 74.9" id="19,10"></path><path d="M 119.7 99.3 L 119.7 88.8 L 189.4 88.8" id="16,9"></path><path d="M 142.9 109.7 L 142.9 102.7 L 189.4 102.7" id="14,8"></path><path d="M 142.9 109.7 L 142.9 116.6 L 189.4 116.6" id="14,7"></path><path d="M 96.5 137.5 L 96.5 130.5 L 189.4 130.5" id="18,6"></path><path d="M 96.5 137.5 L 96.5 144.5 L 189.4 144.5" id="18,5"></path><path d="M 96.5 171.4 L 96.5 158.4 L 189.4 158.4" id="17,4"></path><path d="M 119.7 184.4 L 119.7 172.3 L 189.4 172.3" id="15,3"></path><path d="M 142.9 196.6 L 142.9 186.2 L 189.4 186.2" id="13,2"></path><path d="M 166.1 207.0 L 166.1 200.1 L 189.4 200.1" id="12,1"></path><path d="M 166.1 207.0 L 166.1 214.0 L 189.4 214.0" id="12,0"></path></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:None;stroke-width:1"><g id="node-0" transform="translate(189.369,213.986)"><circle r="0.0"></circle></g><g id="node-1" transform="translate(189.369,200.079)"><circle r="0.0"></circle></g><g id="node-2" transform="translate(189.369,186.173)"><circle r="0.0"></circle></g><g id="node-3" transform="translate(189.369,172.266)"><circle r="0.0"></circle></g><g id="node-4" transform="translate(189.369,158.360)"><circle r="0.0"></circle></g><g id="node-5" transform="translate(189.369,144.453)"><circle r="0.0"></circle></g><g id="node-6" transform="translate(189.369,130.547)"><circle r="0.0"></circle></g><g id="node-7" transform="translate(189.369,116.640)"><circle r="0.0"></circle></g><g id="node-8" transform="translate(189.369,102.734)"><circle r="0.0"></circle></g><g id="node-9" transform="translate(189.369,88.827)"><circle r="0.0"></circle></g><g id="node-10" transform="translate(189.369,74.921)"><circle r="0.0"></circle></g><g id="node-11" transform="translate(189.369,61.014)"><circle r="0.0"></circle></g><g id="node-12" transform="translate(166.141,207.033)"><circle r="6.0"></circle></g><g id="node-13" transform="translate(142.913,196.603)"><circle r="6.0"></circle></g><g id="node-14" transform="translate(142.913,109.687)"><circle r="6.0"></circle></g><g id="node-15" transform="translate(119.684,184.435)"><circle r="6.0"></circle ...
# {
# var modules={};
# })();</script></div></div>

# %%
# Test this on TWO trees, for speed reasons.  If it works for two, it'll work for 100.

class Simulator:
    
    def __init__(self, seed, sptree, ntrees):
        
        # Store initial arguments.
        self.seed = seed # Seed for all instances of the class.  
        self.sptree = sptree # True species tree.
        self.ntrees = ntrees # Number of replicate trees.
        # self.ntips = ntips  Number of tips.
        
        # Objects to be created.
        self.reps = []
        self.seqs = []
        self.raxtrees = []
        self.chrtrees = []
        self.errors = []
        
        # Organize results into a dataframe.
        self.df = pd.DataFrame({
            
            # variable len edges - results of batch tree
            "rate_trees": ["" for i in range(ntrees)],
            
            # variable len edge gene trees inferred by raxml
            "rax_trees": ["" for i in range(ntrees)],
            
            # info about the sequence simulated
            "nsnps": 0,
            
            # ultrametric trees inferred by chronos-correlated
            "chr_trees_relax": ["" for i in range(ntrees)],
            
            # ultrametric trees inferred by chronos-correlated
            "chr_trees_strict": ["" for i in range(ntrees)],
            
            # ... add columns for error calculations
            # ...
        })
        
    # Execute all the major functions in a row.
    def run(self, outdir, file_marker, path, min_ages, max_ages, tips, lamb):
        self.batch_treedata()
        self.batch_ipcoal()
        self.batch_raxml()
        self.batch_chronos()

    def batch_treedata(self, outdir, file_marker):
        '''
        Apply rate variation to the edges of the species tree.
        '''
        
        np.random.seed(self.seed)
        self.reps = [self.sptree for i in range(self.ntrees)]
        reps = []
        counter = 0
        for i in self.reps:
        
            # Increment counter.
            counter +=1
    
            # Set Ne values from an interval onto tree.
            dict_ne = {j.name : np.random.randint(5e5, 5e6) for j in i.get_feature_dict()}
            i = i.set_node_values("Ne", dict_ne)
    
            # Set g values from a normal distribution onto tree.
            dict_g = {j.name : np.random.normal(1, 0.2) for j in i.get_feature_dict()}
            i = i.set_node_values("g", dict_g)
    
            # Divide edge lengths (absolute time) by generation time to convert tree to units of generations.
            i = i.set_node_values(
            "dist",
            {j.name: j.dist / j.g for j in i.get_feature_dict()}
            )
    
            # Save tree to a list and as a separate newick file.
            reps.append(i)
            savefile = outdir + file_marker + '{0:03}'.format(counter) + ".tre"
            i.write(savefile)
            
            # Save changes to trees.
            self.reps = reps
    
        return "Saved " + str(self.ntrees) + " trees."
    
    def batch_ipcoal(self, outdir, file_marker):
        '''
        Generate sequence data on tree variants.
        '''
        
        counter = 0
        seqs = []
        for i in self.reps:
        
            # Increment counter.
            counter += 1
        
            # Run ipcoal.
            model = ipcoal.Model(i, nsamples = 2, seed = self.seed) 
            model.sim_loci(1000, 100) # (loci, bp) 
            
            # Write a diploid phylip file.
            file = model.write_concat_to_phylip(outdir = outdir, diploid = True,
                                      name = file_marker + "_diploid" + '{0:03}'.format(counter) + ".phy")
            seqs.append(outdir + file_marker + "_diploid" + '{0:03}'.format(counter) + ".phy")
            
        # Save the list of concatenated phylip files.    
        self.seqs = seqs
            
    def batch_raxml(self, outdir, file_marker, outdir_for_chronos):
        '''
        Infer raxml trees from sequence data.
        '''
        
        np.random.seed(self.seed)
        raxtrees = []
        counter = 0
        for i in self.seqs:
        
            # Increment counter.
            counter += 1
        
            # Define and run raxml object.
            rax = ipa.raxml(
                name = file_marker + '{0:03}'.format(counter),
                data = i,
                workdir = outdir,
                N = 100,
                T = 10 # Core assignment appropriate for pinky or other external server.
            )
            rax.run(force = True, block = False)
            
            # Take the raxml result and save as a newick string (required format for chronos).
            rax_result = outdir + "RAxML_bipartitions." + file_marker + '{0:03}'.format(counter)
            rax_toytree = toytree.tree(rax_result).root(["r7", "r8", "r9", "r10", "r11"]) # Rooting midpoint of true tree.
            rax_toytree.write(outdir_for_chronos + file_marker + '{0:03}'.format(counter) + ".tre")
            
            # Add raxtree to list.
            raxtrees.append(outdir_for_chronos + file_marker + '{0:03}'.format(counter) + ".tre")
            
        # Save the list of raxtrees.
        self.raxtrees = raxtrees
        
    def batch_chronos(self, path_with_marker, min_ages, max_ages, tip1, tip2, lamb):
        '''
        Run chronos on raxml trees.  Format min_ages, max_ages, tip1 and tip2 as tuples of the same length, formatted with
        double quotes with constituent elements in single quotes.
        Examples: min_ages = "'5000000', '10000000'"; tip1 = "'r0', 'r4'"
        '''
    
        np.random.seed(self.seed)
        chrtrees = []
        counter = 0
        for i in self.raxtrees:
        
            # Increment counter.
            counter += 1
        
            # Rstring with chronos information.
            rstring = f"""library(ape)
btree <- read.tree("{i}")
min_ages <- c{min_ages}
max_ages <- c{max_ages}
tip1 <- c{tip1}
tip2 <- c{tip2}
nodes <- c()
for (i in 1:length(tip1)) {{
    mrca <- getMRCA(btree, c(tip1[i], tip2[i]))
    nodes <- append(nodes, mrca)
}}
calib <- data.frame(node = nodes, age.min = as.numeric(min_ages), age.max = as.numeric(max_ages))
ctree <- chronos(btree, lambda = {lamb}, model = "relaxed", calibration = calib)
write.tree(ctree)"""
            
            # Write the R script to a file.
            with open(path_with_marker + '{0:03}'.format(counter) + ".R", 'w') as out:
                out.write(rstring)
            
            # byte = rstring.encode()
            # temp = tempfile.NamedTemporaryFile()
            # temp.write(byte)
            # temp.seek(0)
            # print(temp.read())
    
            cmd = ["Rscript", path_with_marker + '{0:03}'.format(counter) + ".R"] # Runs R script saved to path.
            out = subprocess.check_output(cmd).decode()
            results, tree = [i.strip().strip('"') for i in out.split("[1]")]
            # return results, tree

            # Add chronos tree to list.
            chrtrees.append(tree)
            
            # temp.close()
    
        # Save the list of chrtrees.
        self.chrtrees = chrtrees
    
    def calculate_error(self):
        "Calculate error between true tree and chronos trees."
        
        errors = []
        
        # Get edge lengths of true tree.
        true_edge_lengths = self.sptree.get_edge_values(feature = "dist")
        
        # For each chrtree, get edge lengths to subtract from true edge lengths.
        for i in self.chrtrees:
            chrtree = toytree.tree(i)
            chr_edge_lengths = chrtree.get_edge_values(feature = "dist")
            subtract_array = true_edge_lengths - chr_edge_lengths
            
            # Square each element in the array.
            squared_array = np.square(subtract_array)
            
            # Sum all elements in the array (sum of squares).
            sum_squares = np.sum(squared_array)
            
            # Add error to list.
            errors.append(sum_squares)
            
        # Save errors.
        self.errors = errors
    
    def batch_mrbayes(self):
        "call mrbayes (maybe using ipa) to infer trees"
        pass

# %%
toytree.tree(sim.raxtrees[0]).write("/home/henry/phylo-timescale/test.tre")

# %%
# Initialize instance of class.
sim = Simulator(seed = 234, sptree = ttree, ntrees = 100)

# %%
sim.batch_treedata("/pinky/henry/treedata/", "ttree")
# Out:
# 'Saved 100 trees.'

# %%
sim.batch_ipcoal("/pinky/henry/ipcoal/", "ttree")
# Out:
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid001.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid002.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid003.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid004.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid005.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid006.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid007.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid008.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid009.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid010.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid011.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid012.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid013.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid014.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid015.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid016.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid017.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid018.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid019.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid020.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid021.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid022.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid023.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid024.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid025.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid026.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid027.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid028.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid029.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid030.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid031.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid032.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid033.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid034.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid035.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid036.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid037.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid038.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid039.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid040.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid041.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid042.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid043.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid044.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid045.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid046.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid047.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid048.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid049.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid050.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid051.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid052.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid053.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid054.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid055.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid056.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid057.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid058.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid059.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid060.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid061.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid062.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid063.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid064.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid065.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid066.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid067.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid068.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid069.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid070.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid071.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid072.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid073.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid074.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid075.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid076.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid077.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid078.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid079.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid080.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid081.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid082.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid083.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid084.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid085.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid086.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid087.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid088.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid089.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid090.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid091.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid092.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid093.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid094.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid095.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid096.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid097.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid098.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid099.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/ipcoal/ttree_diploid100.phy

# %%
sim.batch_raxml("/pinky/henry/raxml/", "ttree", 
                "/pinky/henry/pre-chronos/")
# Out:
# job ttree001 finished successfully
# job ttree002 finished successfully
# job ttree003 finished successfully
# job ttree004 finished successfully
# job ttree005 finished successfully
# job ttree006 finished successfully
# job ttree007 finished successfully
# job ttree008 finished successfully
# job ttree009 finished successfully
# job ttree010 finished successfully
# job ttree011 finished successfully
# job ttree012 finished successfully
# job ttree013 finished successfully
# job ttree014 finished successfully
# job ttree015 finished successfully
# job ttree016 finished successfully
# job ttree017 finished successfully
# job ttree018 finished successfully
# job ttree019 finished successfully
# job ttree020 finished successfully
# job ttree021 finished successfully
# job ttree022 finished successfully
# job ttree023 finished successfully
# job ttree024 finished successfully
# job ttree025 finished successfully
# job ttree026 finished successfully
# job ttree027 finished successfully
# job ttree028 finished successfully
# job ttree029 finished successfully
# job ttree030 finished successfully
# job ttree031 finished successfully
# job ttree032 finished successfully
# job ttree033 finished successfully
# job ttree034 finished successfully
# job ttree035 finished successfully
# job ttree036 finished successfully
# job ttree037 finished successfully
# job ttree038 finished successfully
# job ttree039 finished successfully
# job ttree040 finished successfully
# job ttree041 finished successfully
# job ttree042 finished successfully
# job ttree043 finished successfully
# job ttree044 finished successfully
# job ttree045 finished successfully
# job ttree046 finished successfully
# job ttree047 finished successfully
# job ttree048 finished successfully
# job ttree049 finished successfully
# job ttree050 finished successfully
# job ttree051 finished successfully
# job ttree052 finished successfully
# job ttree053 finished successfully
# job ttree054 finished successfully
# job ttree055 finished successfully
# job ttree056 finished successfully
# job ttree057 finished successfully
# job ttree058 finished successfully
# job ttree059 finished successfully
# job ttree060 finished successfully
# job ttree061 finished successfully
# job ttree062 finished successfully
# job ttree063 finished successfully
# job ttree064 finished successfully
# job ttree065 finished successfully
# job ttree066 finished successfully
# job ttree067 finished successfully
# job ttree068 finished successfully
# job ttree069 finished successfully
# job ttree070 finished successfully
# job ttree071 finished successfully
# job ttree072 finished successfully
# job ttree073 finished successfully
# job ttree074 finished successfully
# job ttree075 finished successfully
# job ttree076 finished successfully
# job ttree077 finished successfully
# job ttree078 finished successfully
# job ttree079 finished successfully
# job ttree080 finished successfully
# job ttree081 finished successfully
# job ttree082 finished successfully
# job ttree083 finished successfully
# job ttree084 finished successfully
# job ttree085 finished successfully
# job ttree086 finished successfully
# job ttree087 finished successfully
# job ttree088 finished successfully
# job ttree089 finished successfully
# job ttree090 finished successfully
# job ttree091 finished successfully
# job ttree092 finished successfully
# job ttree093 finished successfully
# job ttree094 finished successfully
# job ttree096 finished successfully
# job ttree097 finished successfully
# job ttree098 finished successfully
# job ttree099 finished successfully
# job ttree100 finished successfully

# %%
sim.batch_chronos(path_with_marker = "/pinky/henry/post-chronos/ttree", 
                  min_ages = "'3000010', '8000000'", max_ages = "'7000010', '12000000'",
                  tip1 = "'r7', 'r0'", tip2 = "'r9', 'r11'", lamb = 0)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-91-8651e5a740e3> in <module>
#       1 sim.batch_chronos(path_with_marker = "/pinky/henry/post-chronos/ttree",
#       2                   min_ages = "'3000010', '8000000'", max_ages = "'7000010', '12000000'",
# ----> 3                   tip1 = "'r7', 'r0'", tip2 = "'r9', 'r11'", lamb = 0)
#
# <ipython-input-41-7ebe7638b62a> in batch_chronos(self, path_with_marker, min_ages, max_ages, tip1, tip2, lamb)
#     184
#     185             cmd = ["Rscript", path_with_marker + '{0:03}'.format(counter) + ".R"] # Runs R script saved to path.
# --> 186             out = subprocess.check_output(cmd).decode()
#     187             results, tree = [i.strip().strip('"') for i in out.split("[1]")]
#     188             # return results, tree
#
# ~/miniconda3/envs/py37/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     409
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#     413
#
# ~/miniconda3/envs/py37/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     510         if check and retcode:
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#     514
#
# CalledProcessError: Command '['Rscript', '/pinky/henry/post-chronos/ttree001.R']' returned non-zero exit status 1.

# %%
sim.calculate_error()

# %%
sim.errors
# Out:
# [206914486443828.44,
#  206592152408839.53,
#  218704607228958.47,
#  205263440605351.2,
#  208685642441463.44,
#  216359926517103.3,
#  205438777846908.0,
#  208652397939022.16,
#  207263999596179.2,
#  205150169061348.75,
#  205082853424493.0,
#  217116560133326.25,
#  216297279380146.06,
#  215733024668054.9,
#  205491226063911.2,
#  205076691905997.8,
#  206819061330052.4,
#  208700613812382.3,
#  205122181904164.7,
#  206305382065304.62,
#  210042575474977.25,
#  206375715976668.25,
#  205141402338840.72,
#  206956925585458.56,
#  205650922132004.97,
#  207679919239291.8,
#  206828193625891.12,
#  215269832559333.28,
#  205361378021134.56,
#  205095230360214.28,
#  205594599588677.0,
#  209231591671015.03,
#  208233285804201.22,
#  209505454849540.8,
#  207139323199006.25,
#  205197266733256.56,
#  205553642668740.06,
#  212496777367407.06,
#  206515012436419.84,
#  205481805667857.94,
#  206714977479129.06,
#  205069162025264.12,
#  205272195800480.1,
#  205285645574277.03,
#  205936270478587.72,
#  211049660129447.53,
#  205211725687542.2,
#  210262622247066.62,
#  218529377108153.72,
#  205110078189557.06,
#  208458362238387.56,
#  217198397603843.7,
#  208854656023366.72,
#  210003409157612.38,
#  206898016916737.22,
#  215851760959111.25,
#  208273982835538.8,
#  206035808371417.75,
#  208479023197831.25,
#  205066646767554.1,
#  206889163244669.7,
#  208333421706649.94,
#  205531536476070.2,
#  208914079851851.12,
#  217813910456192.38,
#  205066080148243.25,
#  208008154426344.38,
#  208616680070563.6,
#  216112331165597.6,
#  205186117623724.6,
#  208165314900606.47,
#  206151516442932.62,
#  205086466085138.3,
#  205844560468593.94,
#  205221974564352.2,
#  206298486607572.2,
#  212631728633022.44,
#  212383562032094.75,
#  208398485322101.8,
#  205082765025024.62,
#  211065748657139.56,
#  212571007204930.56,
#  205374856745417.38,
#  208684361041499.7,
#  206600258451268.2,
#  206752119298456.25,
#  206963048685243.4,
#  207075603328307.44,
#  207169349419658.1,
#  206890969491723.06,
#  206347027864316.7,
#  205481263050676.12,
#  213673196486205.3,
#  205141398352724.5,
#  205256841251870.22,
#  205459862705037.06,
#  212974107356624.03,
#  206406615247078.75,
#  205537030098189.56,
#  218736357281220.5]

# %%
toytree.tree(sim.raxtrees[56]).draw();
# Out:
# <div class="toyplot" id="t77d6d319744449dba154ea5209ec8405" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="275.0px" id="t681431607d954cb190736656ee645d87" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 265.0 275.0" width="265.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t504f71ce09554a16a4a0ad80c7ccc65d"><clipPath id="td488532351644904ae21eae6ec588315"><rect height="215.0" width="205.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#td488532351644904ae21eae6ec588315)"><g class="toytree-mark-Toytree" id="t337e0c861697459f9fd601fa91ffbe1f"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 51.8 114.2 L 51.8 74.1 L 56.2 74.1" id="22,21"></path><path d="M 51.8 114.2 L 51.8 154.4 L 56.2 154.4" id="22,20"></path><path d="M 56.2 74.1 L 56.2 87.1 L 61.9 87.1" id="21,19"></path><path d="M 56.2 154.4 L 56.2 137.5 L 69.9 137.5" id="20,18"></path><path d="M 56.2 154.4 L 56.2 171.4 L 68.1 171.4" id="20,17"></path><path d="M 61.9 87.1 L 61.9 99.3 L 68.8 99.3" id="19,16"></path><path d="M 68.1 171.4 L 68.1 184.