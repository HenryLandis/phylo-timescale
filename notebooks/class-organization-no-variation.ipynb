# %%
import toytree
import pandas as pd
import numpy as np
import ipcoal
import ipyrad.analysis as ipa
import tempfile
import subprocess
import matplotlib.pyplot as plt

# %%
tre = toytree.rtree.unittree(12, treeheight = 10e6, seed = 102)
tree = tre.write("/home/henry/phylo-timescale/tree.tre")

ttree = toytree.tree("/home/henry/phylo-timescale/tree.tre")
ttree.draw(node_labels="idx", node_sizes=12);
# Out:
# <div class="toyplot" id="td8638e0e3e8b446fabacb81fe10fa40e" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="275.0px" id="t6e6805e729b0448da83e65e5f8aa35e2" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 265.0 275.0" width="265.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tcffbf4f5906144eb97eb1513d8473341"><clipPath id="t90723abe719e47e78905d74cdd4aa8b7"><rect height="215.0" width="205.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t90723abe719e47e78905d74cdd4aa8b7)"><g class="toytree-mark-Toytree" id="t98d8fb9bbb6a4c7bb20e61573e9edb49"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 50.0 114.2 L 50.0 74.1 L 73.2 74.1" id="22,21"></path><path d="M 50.0 114.2 L 50.0 154.4 L 73.2 154.4" id="22,20"></path><path d="M 73.2 74.1 L 73.2 87.1 L 96.5 87.1" id="21,19"></path><path d="M 73.2 154.4 L 73.2 137.5 L 96.5 137.5" id="20,18"></path><path d="M 73.2 154.4 L 73.2 171.4 L 96.5 171.4" id="20,17"></path><path d="M 96.5 87.1 L 96.5 99.3 L 119.7 99.3" id="19,16"></path><path d="M 96.5 171.4 L 96.5 184.4 L 119.7 184.4" id="17,15"></path><path d="M 119.7 99.3 L 119.7 109.7 L 142.9 109.7" id="16,14"></path><path d="M 119.7 184.4 L 119.7 196.6 L 142.9 196.6" id="15,13"></path><path d="M 142.9 196.6 L 142.9 207.0 L 166.1 207.0" id="13,12"></path><path d="M 73.2 74.1 L 73.2 61.0 L 189.4 61.0" id="21,11"></path><path d="M 96.5 87.1 L 96.5 74.9 L 189.4 74.9" id="19,10"></path><path d="M 119.7 99.3 L 119.7 88.8 L 189.4 88.8" id="16,9"></path><path d="M 142.9 109.7 L 142.9 102.7 L 189.4 102.7" id="14,8"></path><path d="M 142.9 109.7 L 142.9 116.6 L 189.4 116.6" id="14,7"></path><path d="M 96.5 137.5 L 96.5 130.5 L 189.4 130.5" id="18,6"></path><path d="M 96.5 137.5 L 96.5 144.5 L 189.4 144.5" id="18,5"></path><path d="M 96.5 171.4 L 96.5 158.4 L 189.4 158.4" id="17,4"></path><path d="M 119.7 184.4 L 119.7 172.3 L 189.4 172.3" id="15,3"></path><path d="M 142.9 196.6 L 142.9 186.2 L 189.4 186.2" id="13,2"></path><path d="M 166.1 207.0 L 166.1 200.1 L 189.4 200.1" id="12,1"></path><path d="M 166.1 207.0 L 166.1 214.0 L 189.4 214.0" id="12,0"></path></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:None;stroke-width:1"><g id="node-0" transform="translate(189.369,213.986)"><circle r="0.0"></circle></g><g id="node-1" transform="translate(189.369,200.079)"><circle r="0.0"></circle></g><g id="node-2" transform="translate(189.369,186.173)"><circle r="0.0"></circle></g><g id="node-3" transform="translate(189.369,172.266)"><circle r="0.0"></circle></g><g id="node-4" transform="translate(189.369,158.360)"><circle r="0.0"></circle></g><g id="node-5" transform="translate(189.369,144.453)"><circle r="0.0"></circle></g><g id="node-6" transform="translate(189.369,130.547)"><circle r="0.0"></circle></g><g id="node-7" transform="translate(189.369,116.640)"><circle r="0.0"></circle></g><g id="node-8" transform="translate(189.369,102.734)"><circle r="0.0"></circle></g><g id="node-9" transform="translate(189.369,88.827)"><circle r="0.0"></circle></g><g id="node-10" transform="translate(189.369,74.921)"><circle r="0.0"></circle></g><g id="node-11" transform="translate(189.369,61.014)"><circle r="0.0"></circle></g><g id="node-12" transform="translate(166.141,207.033)"><circle r="6.0"></circle></g><g id="node-13" transform="translate(142.913,196.603)"><circle r="6.0"></circle></g><g id="node-14" transform="translate(142.913,109.687)"><circle r="6.0"></circle></g><g id="node-15" transform="translate(119.684,184.435)"><circle r="6.0"></circle ...
# {
# var modules={};
# })();</script></div></div>

# %%
class Simulator:
    
    def __init__(self, seed, sptree, ntrees):
        
        # Store initial arguments.
        self.seed = seed # Seed for all instances of the class.  
        self.sptree = sptree # True species tree.
        self.ntrees = ntrees # Number of replicate trees.
        # self.ntips = ntips  Number of tips.
        
        # Objects to be created.
        self.reps = []
        self.seqs = []
        self.raxtrees = []
        
        # Organize results into a dataframe.
        self.df = pd.DataFrame({
            
            # Trees with rate variation applied to edges.
            "rate_trees": ["" for i in range(ntrees)],
            
            # Gene trees with variable edge lengths inferred by RAxML.
            "rax_trees": ["" for i in range(ntrees)],
            
            # Number of SNPs from RAxML trees.
            "nsnps": 0,

            # Ultrametric trees inferred from chronos under relaxed model.
            "chr_trees_relax": ["" for i in range(ntrees)],
            
            # # Ultrametric trees inferred from chronos under strict model.
            "chr_trees_strict": ["" for i in range(ntrees)],
            
            # Error between tree from chronos and true tree.
            "error" : ["" for i in range(ntrees)]
        })
        
    # Execute all the major functions in a row.
    def run(self, outdir, file_marker, path, min_ages, max_ages, tips, lamb):
        self.batch_treedata()
        self.batch_ipcoal()
        self.batch_raxml()
        self.batch_chronos()

    def batch_treedata(self, outdir, file_marker):
        '''
        Apply rate variation to the edges of the species tree.
        '''
        
        np.random.seed(self.seed)
        self.reps = [self.sptree for i in range(self.ntrees)]
        reps = []
        counter = 0
        for i in self.reps:
        
            # Increment counter.
            counter +=1
    
            # Set Ne values from an interval onto tree.
            dict_ne = {j.name : np.random.randint(5e5, 5e6) for j in i.get_feature_dict()}
            i = i.set_node_values("Ne", dict_ne)
    
            # Set g values from a normal distribution onto tree.
            dict_g = {j.name : np.random.normal(1, 0.2) for j in i.get_feature_dict()}
            i = i.set_node_values("g", dict_g)
    
            # Divide edge lengths (absolute time) by generation time to convert tree to units of generations.
            i = i.set_node_values(
            "dist",
            {j.name: j.dist / j.g for j in i.get_feature_dict()}
            )
    
            # Save tree to a list and as a separate newick file.
            reps.append(i)
            savefile = outdir + file_marker + '{0:03}'.format(counter) + ".tre"
            i.write(savefile)
            
        # Save to instance variable and dataframe.
        self.reps = reps
        for i in self.df.index:
            self.df.loc[i, "rate_trees"] = self.reps[i]
    
        return "Saved " + str(self.ntrees) + " trees."
    
    def batch_ipcoal(self, outdir, file_marker):
        '''
        Generate sequence data on tree variants.
        '''
        
        counter = 0
        seqs = []
        for i in self.reps:
        
            # Increment counter.
            counter += 1
        
            # Run ipcoal.
            model = ipcoal.Model(i, nsamples = 2, seed = self.seed) 
            model.sim_loci(1000, 100) # (loci, bp) 
            
            # Write a diploid phylip file.
            file = model.write_concat_to_phylip(outdir = outdir, diploid = True,
                                      name = file_marker + "_diploid" + '{0:03}'.format(counter) + ".phy")
            seqs.append(outdir + file_marker + "_diploid" + '{0:03}'.format(counter) + ".phy")
            
        # Save the list of concatenated phylip files to instance variable.   
        self.seqs = seqs
            
    def batch_raxml(self, outdir, file_marker, outdir_for_chronos):
        '''
        Infer raxml trees from sequence data.
        '''
        
        np.random.seed(self.seed)
        raxtrees = []
        counter = 0
        for i in self.seqs:
        
            # Increment counter.
            counter += 1
        
            # Define and run raxml object.
            rax = ipa.raxml(
                name = file_marker + '{0:03}'.format(counter),
                data = i,
                workdir = outdir,
                N = 100,
                T = 10 # Core assignment appropriate for pinky or other external server.
            )
            rax.run(force = True, block = False)
            
            # Take the raxml result and save as a newick string (required format for chronos).
            rax_result = outdir + "RAxML_bipartitions." + file_marker + '{0:03}'.format(counter)
            rax_toytree = toytree.tree(rax_result).root(["r7", "r8", "r9", "r10", "r11"]) # Rooting midpoint of true tree.
            rax_toytree.write(outdir_for_chronos + file_marker + '{0:03}'.format(counter) + ".tre")
            
            # Add raxtree to list.
            # raxtrees.append(outdir_for_chronos + file_marker + '{0:03}'.format(counter) + ".tre")
            raxtrees.append(rax_toytree)
            
        # Save to instance variable and dataframe.
        self.raxtrees = raxtrees
        for i in self.df.index:
            self.df.loc[i, "rax_trees"] = self.raxtrees[i]
            
class Analysis:
    
    def __init__(self, seed, sptree, df):
        
        # Store initial arguments.
        self.seed = seed
        self.sptree = sptree
        self.df = df
        
        # Objects to be created.
        self.chrtrees = []
        self.errors = []
        
    def batch_chronos(self, path_with_marker, min_ages, max_ages, tip1, tip2, lamb):
        '''
        Run chronos on raxml trees.  Format min_ages, max_ages, tip1 and tip2 as tuples of the same length, formatted with
        double quotes enclosing parentheses, with constituent elements in single quotes.
        Examples: min_ages = "('5000000', '10000000')"; tip1 = "('r0', 'r4')"
        '''
    
        np.random.seed(self.seed)
        chrtrees = []
        counter = 0
        for i in self.df["rax_trees"]:
        
            # Increment counter.
            counter += 1
        
            # Rstring with chronos information.
            rstring = f"""library(ape)
btree <- read.tree("{i}")
min_ages <- c{min_ages}
max_ages <- c{max_ages}
tip1 <- c{tip1}
tip2 <- c{tip2}
nodes <- c()
for (i in 1:length(tip1)) {{
    mrca <- getMRCA(btree, c(tip1[i], tip2[i]))
    nodes <- append(nodes, mrca)
}}
calib <- data.frame(node = nodes, age.min = as.numeric(min_ages), age.max = as.numeric(max_ages))
ctree <- chronos(btree, lambda = {lamb}, model = "relaxed", calibration = calib)
write.tree(ctree)"""
            
            # Write the R script to a file.
            with open(path_with_marker + '{0:03}'.format(counter) + ".R", 'w') as out:
                out.write(rstring)
            
            # byte = rstring.encode()
            # temp = tempfile.NamedTemporaryFile()
            # temp.write(byte)
            # temp.seek(0)
            # print(temp.read())
    
            cmd = ["Rscript", path_with_marker + '{0:03}'.format(counter) + ".R"] # Runs R script saved to path.
            out = subprocess.check_output(cmd).decode()
            results, tree = [i.strip().strip('"') for i in out.split("[1]")]

            # Add chronos tree to list.
            chrtrees.append(tree)
            
            # temp.close()
    
        # Save to instance variable and dataframe.
        self.chrtrees = chrtrees
        for i in self.df.index:
            self.df.loc[i, "chr_trees_relax"] = self.chrtrees[i]
    
    def calculate_error(self):
        "Calculate error between true tree and chronos trees."
        
        errors = []
        
        # Get edge lengths of true tree.
        true_edge_lengths = self.sptree.get_edge_values(feature = "height")
        
        # For each chrtree, get edge lengths to subtract from true edge lengths.
        for i in self.chrtrees:
            chrtree = toytree.tree(i)
            chr_edge_lengths = chrtree.get_edge_values(feature = "height")
            subtract_array = true_edge_lengths - chr_edge_lengths
            
            # Square each element in the array.
            squared_array = np.square(subtract_array)
            
            # Sum all elements in the array (sum of squares).
            sum_squares = np.sum(squared_array)
            
            # Add error to list.
            errors.append(sum_squares)
            
        # Save to instance variable and dataframe.
        self.errors = errors
        for i in self.df.index:
            self.df.loc[i, "error"] = self.errors[i]
    
    def batch_mrbayes(self):
        "call mrbayes (maybe using ipa) to infer trees"
        pass

# %%
# Initialize instance of class.
sim = Simulator(seed = 234, sptree = ttree, ntrees = 100)

# %%
sim.batch_treedata("/pinky/henry/no-variation/treedata/", "ttree")
# Out:
# 'Saved 100 trees.'

# %%
sim.batch_ipcoal("/pinky/henry/no-variation/ipcoal/", "ttree")
# Out:
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid001.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid002.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid003.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid004.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid005.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid006.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid007.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid008.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid009.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid010.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid011.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid012.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid013.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid014.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid015.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid016.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid017.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid018.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid019.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid020.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid021.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid022.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid023.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid024.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid025.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid026.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid027.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid028.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid029.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid030.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid031.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid032.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid033.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid034.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid035.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid036.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid037.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid038.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid039.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid040.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid041.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid042.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid043.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid044.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid045.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid046.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid047.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid048.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid049.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid050.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid051.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid052.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid053.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid054.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid055.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid056.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid057.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid058.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid059.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid060.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid061.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid062.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid063.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid064.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid065.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid066.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid067.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid068.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid069.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid070.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid071.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid072.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid073.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid074.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid075.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid076.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid077.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid078.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid079.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid080.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid081.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid082.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid083.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid084.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid085.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid086.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid087.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid088.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid089.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid090.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid091.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid092.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid093.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid094.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid095.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid096.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid097.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid098.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid099.phy
# wrote concat locus (12 x 100000bp) to /pinky/henry/no-variation/ipcoal/ttree_diploid100.phy

# %%
sim.batch_raxml("/pinky/henry/no-variation/raxml/", "ttree", 
                "/pinky/henry/no-variation/pre-chronos/")
# Out:
# job ttree001 finished successfully
# job ttree002 finished successfully
# job ttree003 finished successfully
# job ttree004 finished successfully
# job ttree005 finished successfully
# job ttree006 finished successfully
# job ttree007 finished successfully
# job ttree008 finished successfully
# job ttree009 finished successfully
# job ttree010 finished successfully
# job ttree011 finished successfully
# job ttree012 finished successfully
# job ttree013 finished successfully
# job ttree014 finished successfully
# job ttree015 finished successfully
# job ttree016 finished successfully
# job ttree017 finished successfully
# job ttree018 finished successfully
# job ttree019 finished successfully
# job ttree020 finished successfully
# job ttree021 finished successfully
# job ttree022 finished successfully
# job ttree023 finished successfully
# job ttree024 finished successfully
# job ttree025 finished successfully
# job ttree026 finished successfully
# job ttree027 finished successfully
# job ttree028 finished successfully
# job ttree029 finished successfully
# job ttree030 finished successfully
# job ttree031 finished successfully
# job ttree032 finished successfully
# job ttree033 finished successfully
# job ttree034 finished successfully
# job ttree035 finished successfully
# job ttree036 finished successfully
# job ttree037 finished successfully
# job ttree038 finished successfully
# job ttree039 finished successfully
# job ttree040 finished successfully
# job ttree041 finished successfully
# job ttree042 finished successfully
# job ttree043 finished successfully
# job ttree044 finished successfully
# job ttree045 finished successfully
# job ttree046 finished successfully
# job ttree047 finished successfully
# job ttree048 finished successfully
# job ttree049 finished successfully
# job ttree050 finished successfully
# job ttree051 finished successfully
# job ttree052 finished successfully
# job ttree053 finished successfully
# job ttree054 finished successfully
# job ttree055 finished successfully
# job ttree056 finished successfully
# job ttree057 finished successfully
# job ttree058 finished successfully
# job ttree059 finished successfully
# job ttree060 finished successfully
# job ttree061 finished successfully
# job ttree062 finished successfully
# job ttree063 finished successfully
# job ttree064 finished successfully
# job ttree065 finished successfully
# job ttree066 finished successfully
# job ttree067 finished successfully
# job ttree068 finished successfully
# job ttree069 finished successfully
# job ttree070 finished successfully
# job ttree071 finished successfully
# job ttree072 finished successfully
# job ttree073 finished successfully
# job ttree074 finished successfully
# job ttree075 finished successfully
# job ttree076 finished successfully
# job ttree077 finished successfully
# job ttree078 finished successfully
# job ttree079 finished successfully
# job ttree080 finished successfully
# job ttree081 finished successfully
# job ttree082 finished successfully
# job ttree083 finished successfully
# job ttree084 finished successfully
# job ttree085 finished successfully
# job ttree086 finished successfully
# job ttree087 finished successfully
# job ttree088 finished successfully
# job ttree089 finished successfully
# job ttree090 finished successfully
# job ttree091 finished successfully
# job ttree092 finished successfully
# job ttree093 finished successfully
# job ttree094 finished successfully
# job ttree095 finished successfully
# job ttree096 finished successfully
# job ttree097 finished successfully
# job ttree098 finished successfully
# job ttree099 finished successfully
# job ttree100 finished successfully

# %%
A1 = Analysis(seed = sim.seed, df = sim.df.copy(), sptree = sim.sptree)
A2 = Analysis(seed = sim.seed, df = sim.df.copy(), sptree = sim.sptree)
A3 = Analysis(seed = sim.seed, df = sim.df.copy(), sptree = sim.sptree)

# %%
# Shallow and root nodes.
A1.batch_chronos(path_with_marker = "/pinky/henry/no-variation/post-chronos/ttree", 
                  min_ages = "('3000010', '8000000')", max_ages = "('7000010', '12000000')",
                  tip1 = "('r7', 'r0')", tip2 = "('r9', 'r11')", lamb = 0)

# Shallow node only.
A2.batch_chronos(path_with_marker = "/pinky/henry/no-variation/post-chronos2/ttree", 
                  min_ages = "('3000010')", max_ages = "('7000010')",
                  tip1 = "('r7')", tip2 = "('r9')", lamb = 0)

# Root node only.
A3.batch_chronos(path_with_marker = "/pinky/henry/no-variation/post-chronos3/ttree", 
                  min_ages = "('8000000')", max_ages = "('12000000')",
                  tip1 = "('r0')", tip2 = "('r11')", lamb = 0)

# %%
A1.calculate_error()
A2.calculate_error()
A3.calculate_error()

# %%
A4 = Analysis(seed = sim.seed, df = sim.df.copy(), sptree = sim.sptree)
A5 = Analysis(seed = sim.seed, df = sim.df.copy(), sptree = sim.sptree)
A6 = Analysis(seed = sim.seed, df = sim.df.copy(), sptree = sim.sptree)

# %%
# Shallow and root nodes.
A4.batch_chronos(path_with_marker = "/pinky/henry/no-variation/post-chronos/utree", 
                  min_ages = "('1000010', '5000000')", max_ages = "('9000010', '15000000')",
                  tip1 = "('r7', 'r0')", tip2 = "('r9', 'r11')", lamb = 0)

# Shallow node only.
A5.batch_chronos(path_with_marker = "/pinky/henry/no-variation/post-chronos2/utree", 
                  min_ages = "('1000010')", max_ages = "('9000010')",
                  tip1 = "('r7')", tip2 = "('r9')", lamb = 0)

# Root node only.
A6.batch_chronos(path_with_marker = "/pinky/henry/no-variation/post-chronos3/utree", 
                  min_ages = "('5000000')", max_ages = "('15000000')",
                  tip1 = "('r0')", tip2 = "('r11')", lamb = 0)

# %%
A4.calculate_error()
A5.calculate_error()
A6.calculate_error()

# %%
bins = np.linspace(5e13, 3e14, 100)

plt.hist(A1.df["error"], bins, facecolor='b', alpha=0.5, label = "Shallow + root")
plt.hist(A2.df["error"], bins, facecolor='r', alpha=0.5, label = "Shallow only")
plt.hist(A3.df["error"], bins, facecolor='g', alpha=0.5, label = "Root only")

plt.legend(loc='upper right')
plt.show()

# %%
bins = np.linspace(5e13, 1.5e14, 100)

plt.hist(A1.df["error"], bins, facecolor='b', alpha=0.5, label = "Shallow + root")
plt.hist(A2.df["error"], bins, facecolor='r', alpha=0.5, label = "Shallow only")
plt.hist(A3.df["error"], bins, facecolor='g', alpha=0.5, label = "Root only")

plt.legend(loc='upper right')
plt.show()

# %%
bins = np.linspace(5e13, 7e14, 100)

plt.hist(A4.df["error"], bins, facecolor='b', alpha=0.5, label = "Shallow + root")
plt.hist(A5.df["error"], bins, facecolor='r', alpha=0.5, label = "Shallow only")
plt.hist(A6.df["error"], bins, facecolor='g', alpha=0.5, label = "Root only")

plt.legend(loc='upper right')
plt.show()

# %%
bins = np.linspace(5e13, 4e14, 100)

plt.hist(A4.df["error"], bins, facecolor='b', alpha=0.5, label = "Shallow + root")
plt.hist(A5.df["error"], bins, facecolor='r', alpha=0.5, label = "Shallow only")
plt.hist(A6.df["error"], bins, facecolor='g', alpha=0.5, label = "Root only")

plt.legend(loc='upper right')
plt.show()
